# %% [markdown]
# ### This file (pro_fb_ref_sourcing.ipynb) will:
#  + take in the list of all NFL Quarterbacks Drafted from draft_history.csv
#  + build links for each player at pro-football_reference
#  + load the NFL football data for each player
#  + Export:
#        + ../sourcing_artifacts/pfb_ref_sourcing_output.pkl, ../sourcing_artifacts/pfb_ref_sourcing_output.csv
#        + ../sourcing_artifacts/pfb_ref_sourcing_output_fails.pkl", ../sourcing_artifacts/pfb_ref_sourcing_output_fails.csv"

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
# import csv
csv_path = "../sourcing_artifacts/draft_history.csv"
df = pd.read_csv(csv_path)
display(df.head())
# Out:
#    Year  No.  Round  Pick  Player            Name        Team          College
# 0  2024    1      1     1       1  Caleb Williams       Bears              USC
# 1  2024    2      1     2       2  Jayden Daniels  Commanders  Louisiana State
# 2  2024    3      1     3       3      Drake Maye    Patriots   North Carolina
# 3  2024    4      1     8       8   Michael Penix     Falcons       Washington
# 4  2024    5      1    10      10   J.J. McCarthy     Vikings         Michigan

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Convert 'Year' column to numeric, forcing errors to NaN, then drop rows with NaN in 'Year'
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')
df = df.dropna(subset=['Year'])

# Now filter with the cleaned 'Year' column and select the 'Year' and 'Name' columns
qb_names_to_1969 = df.loc[(df["Year"] > 1900) & (df["Year"] < 1970), ['Year', 'Name']].reset_index(drop=True)
display(len(qb_names_to_1969))
display(qb_names_to_1969.head())

qb_names_1970_9= df.loc[(df["Year"] >= 1970) & (df["Year"] <= 1979), ['Year', 'Name']].reset_index(drop=True)
display(len(qb_names_1970_9))
display(qb_names_1970_9.head())

qb_names_1980_9= df.loc[(df["Year"] >= 1980) & (df["Year"] <= 1989), ['Year', 'Name']].reset_index(drop=True)
display(len(qb_names_1980_9))
display(qb_names_1980_9)

qb_names_1990_9= df.loc[(df["Year"] >= 1990) & (df["Year"] <= 1999), ['Year', 'Name']].reset_index(drop=True)
display(len(qb_names_1990_9))
display(qb_names_1990_9)

qb_names_2000_9= df.loc[(df["Year"] >= 2000) & (df["Year"] <= 2009), ['Year', 'Name']].reset_index(drop=True)
display(len(qb_names_2000_9))
display(qb_names_2000_9)

qb_names_2010_9= df.loc[(df["Year"] >= 2010) & (df["Year"] <= 2019), ['Year', 'Name']].reset_index(drop=True)
display(len(qb_names_2010_9))
display(qb_names_2010_9)

qb_names_2020_= df.loc[(df["Year"] >= 2020), ['Year', 'Name']].reset_index(drop=True)
display(len(qb_names_2020_))
display(qb_names_2020_)
# Out:
# 289
#      Year            Name
# 0  1969.0       Greg Cook
# 1  1969.0    Marty Domres
# 2  1969.0  Terry Hanratty
# 3  1969.0  Bobby Douglass
# 4  1969.0      Al Woodall
# 188
#      Year           Name
# 0  1979.0  Jack Thompson
# 1  1979.0     Phil Simms
# 2  1979.0   Steve Fuller
# 3  1979.0    Joe Montana
# 4  1979.0     Steve Dils
# 156
#        Year                Name
# 0    1989.0         Troy Aikman
# 1    1989.0         Mike Elkins
# 2    1989.0  Billy Joe Tolliver
# 3    1989.0      Anthony Dilweg
# 4    1989.0        Erik Wilhelm
# ..      ...                 ...
# 151  1980.0         Dan Hartwig
# 152  1980.0       Turk Schonert
# 153  1980.0         Mike Wright
# 154  1980.0        Jimmy Jordan
# 155  1980.0       Kevin Scanlon
#
# [156 rows x 2 columns]
# 124
#        Year              Name
# 0    1999.0         Tim Couch
# 1    1999.0    Donovan McNabb
# 2    1999.0       Akili Smith
# 3    1999.0  Daunte Culpepper
# 4    1999.0       Cade McNown
# ..      ...               ...
# 119  1990.0       Todd Hammel
# 120  1990.0      Gene Benhart
# 121  1990.0       John Gromos
# 122  1990.0      Major Harris
# 123  1990.0      Reggie Slack
#
# [124 rows x 2 columns]
# 130
#        Year              Name
# 0    2009.0  Matthew Stafford
# 1    2009.0      Mark Sanchez
# 2    2009.0      Josh Freeman
# 3    2009.0         Pat White
# 4    2009.0     Stephen McGee
# ..      ...               ...
# 125  2000.0        Todd Husak
# 126  2000.0     JaJuan Seider
# 127  2000.0        Tim Rattay
# 128  2000.0   Jarious Jackson
# 129  2000.0      Joe Hamilton
#
# [130 rows x 2 columns]
# 118
#        Year            Name
# 0    2019.0    Kyler Murray
# 1    2019.0    Daniel Jones
# 2    2019.0  Dwayne Haskins
# 3    2019.0       Drew Lock
# 4    2019.0      Will Grier
# ..      ...             ...
# 113  2010.0        Joe Webb
# 114  2010.0       Tony Pike
# 115  2010.0      Levi Brown
# 116  2010.0   Sean Canfield
# 117  2010.0    Zac Robinson
#
# [118 rows x 2 columns]
# 57
#       Year                      Name
# 0   2024.0            Caleb Williams
# 1   2024.0            Jayden Daniels
# 2   2024.0                Drake Maye
# 3   2024.0             Michael Penix
# 4   2024.0             J.J. McCarthy
# 5   2024.0                    Bo Nix
# 6   2024.0           Spencer Rattler
# 7   2024.0             Jordan Travis
# 8   2024.0                Joe Milton
# 9   2024.0               Devin Leary
# 10  2024.0             Michael Pratt
# 11  2023.0               Bryce Young
# 12  2023.0               C.J. Stroud
# 13  2023.0        Anthony Richardson
# 14  2023.0                Will Levis
# 15  2023.0             Hendon Hooker
# 16  2023.0               Jake Haener
# 17  2023.0           Stetson Bennett
# 18  2023.0           Aidan O'Connell
# 19  2023.0              Clayton Tune
# 20  2023.0  Dorian Thompson-Robinson
# 21  2023.0             Sean Clifford
# 22  2023.0                Jaren Hall
# 23  2023.0              Tanner McKee
# 24  2023.0                Max Duggan
# 25  2022.0             Kenny Pickett
# 26  2022.0            Desmond Ridder
# 27  2022.0              Malik Willis
# 28  2022.0               Matt Corral
# 29  2022.0              Bailey Zappe
# 30  2022.0                Sam Howell
# 31  2022.0            Chris Oladokun
# 32  2022.0           Skylar Thompson
# 33  2022.0               Brock Purdy
# 34  2021.0           Trevor Lawrence
# 35  2021.0               Zach Wilson
# 36  2021.0                Trey Lance
# 37  2021.0             Justin Fields
# 38  2021.0                 Mac Jones
# 39  2021.0                Kyle Trask
# 40  2021.0               Kellen Mond
# 41  2021.0               Davis Mills
# 42  2021.0                  Ian Book
# 43  2021.0              Sam Ehlinger
# 44  2020.0                Joe Burrow
# 45  2020.0            Tua Tagovailoa
# 46  2020.0            Justin Herbert
# 47  2020.0               Jordan Love
# 48  2020.0               Jalen Hurts
# 49  2020.0               Jacob Eason
# 50  2020.0              James Morgan
# 51  2020.0                Jake Fromm
# 52  2020.0                Jake Luton
# 53  2020.0             Cole McDonald
# 54  2020.0               Ben DiNucci
# 55  2020.0             Tommy Stevens
# 56  2020.0              Nate Stanley

# %%
import re

def get_weighted_career_av(soup):
    # Locate the div with id 'meta'
    meta_div = soup.find('div', id='meta')
    
    # Initialize variables for storing the AV value and rank
    weighted_av = None
    overall_rank = None
    
    if meta_div:
        # Find text with the "Weighted Career AV" pattern
        av_match = re.search(r'(\d+)\s\((\d+)(?:st|nd|rd|th) overall since 1960\)', meta_div.text)
        
        if av_match:
            weighted_av = av_match.group(1)  # First capture group for the AV number
            overall_rank = av_match.group(2)  # Second capture group for the rank number
    
    if not weighted_av:
        print("\t xx No 'Weighted Career AV' found.")
    else:
        print(f"\t ** Weighted Career AV: {weighted_av}, Overall Rank: {overall_rank}")
    
    return weighted_av, overall_rank

# %%
import re
from bs4 import BeautifulSoup

def get_qb_header_data(soup):
    qb_header_data = {
        'throws': '', 'hall_of_fame': '', 'college': '', 'high_school': '',
        'weighted_career_av': '', 'overall_rank': '', 'college_stats': '',
        'draft_team': '', 'draft_round': '', 'draft_pick': '', 'draft_year': ''
    }
    try:
        # Extract Throws
        throws_tag = soup.find('strong', string='Throws:')
        if throws_tag and throws_tag.next_sibling:
            qb_header_data['throws'] = throws_tag.next_sibling.strip()

        # Extract College
        college_tag = soup.find('strong', text='College')
        if college_tag:
            college = college_tag.find_next('a')
            if college:
                qb_header_data['college'] = college.text.strip()

        # Extract College Stats URL
        college_stats_tag = soup.find('a', href=re.compile(r'https://www.sports-reference.com/cfb/players/'))
        if college_stats_tag:
            qb_header_data['college_stats'] = college_stats_tag['href']

        # Extract Weighted Career AV (wAV) and Overall Rank
        # Call to get_weighted_career_av
        weighted_av, overall_rank = get_weighted_career_av(soup)
        if weighted_av and overall_rank:
            qb_header_data['weighted_career_av'] = weighted_av
            qb_header_data['overall_rank'] = overall_rank

        # Extract High School
        high_school_tag = soup.find('strong', text='High School')
        if high_school_tag:
            high_school = high_school_tag.find_next('a')
            if high_school:
                qb_header_data['high_school'] = high_school.text.strip()

        # Extract Hall of Fame year (hof)
        hof_tag = re.search(r'Hall of Fame.*?(\d{4})', str(soup))
        if hof_tag:
            qb_header_data['hall_of_fame'] = hof_tag.group(1)

        # Extract Draft Team, Round, Pick, and Year
        draft_team_tag = re.search(r'Draft.*?<a.*?>(.*?)</a>', str(soup))
        if draft_team_tag:
            qb_header_data['draft_team'] = draft_team_tag.group(1)
        draft_round_tag = re.search(r'in the (\d+)(?:st|nd|rd|th) round', str(soup))
        if draft_round_tag:
            qb_header_data['draft_round'] = draft_round_tag.group(1)
        draft_pick_tag = re.search(r'\((\d+)(?:st|nd|rd|th) overall\)', str(soup))
        if draft_pick_tag:
            qb_header_data['draft_pick'] = draft_pick_tag.group(1)
        draft_year_tag = re.search(r'(\d{4}) NFL Draft', str(soup))
        if draft_year_tag:
            qb_header_data['draft_year'] = draft_year_tag.group(1)

    except AttributeError as e:
        print(f"An error occurred: {e}")
    return qb_header_data

# %%
def get_summary_stats(soup):
    summary_stats = {}
    try:
        summary = soup.find('div', {'class': 'stats_pullout'})
        summary_stats['games_played'] = summary.find('span', string='G').find_next('p').text.strip()
        summary_stats['approximate_value'] = summary.find('span', string='AV').find_next('p').text.strip()
        summary_stats['qb_record'] = summary.find('span', string='QBrec').find_next('p').text.strip()
        summary_stats['completion_percentage'] = summary.find('span', string='Cmp%').find_next('p').text.strip()
        summary_stats['passing_yards'] = summary.find('span', string='Yds').find_next('p').text.strip()
        summary_stats['yards_per_attempt'] = summary.find('span', string='Y/A').find_next('p').text.strip()
        summary_stats['touchdowns'] = summary.find('span', string='TD').find_next('p').text.strip()
        summary_stats['interceptions'] = summary.find('span', string='Int').find_next('p').text.strip()
        summary_stats['fantasy_points'] = summary.find('span', string='FantPt').find_next('p').text.strip()
    except AttributeError:
        summary_stats = {key: "N/A" for key in ['games_played', 'approximate_value', 'qb_record', 'completion_percentage', 'passing_yards', 'yards_per_attempt', 'touchdowns', 'interceptions', 'fantasy_points']}
    return summary_stats


def get_recognition(soup):
    recognition_data = {}
    try:
        bling = soup.find('ul', id='bling')
        recognition_data['all_star'] = [li.get_text(strip=True) for li in bling.find_all('li', class_='all_star')]
        recognition_data['uniforms'] = [a['data-tip'] for a in soup.find('div', class_='uni_holder').find_all('a')]
    except AttributeError:
        recognition_data = {key: "N/A" for key in ['all_star', 'uniforms']}
    return recognition_data

# %%
import re

def get_faq(soup):
    faq_data = {}
    keyword_patterns = {
        'when_born': re.compile(r'when.*born', re.IGNORECASE),
        'where_born': re.compile(r'where.*born', re.IGNORECASE),
        'height': re.compile(r'tall', re.IGNORECASE),
        'weight': re.compile(r'weigh', re.IGNORECASE),
        'games_played': re.compile(r'games.*play', re.IGNORECASE),
        'pass_yards': re.compile(r'passing.*yards', re.IGNORECASE),
        'TD': re.compile(r'touchdowns', re.IGNORECASE),
        'superbowls': re.compile(r'Super Bowls', re.IGNORECASE),
        'retire_year': re.compile(r'retire', re.IGNORECASE),
        'nickname': re.compile(r'nicknames', re.IGNORECASE)
    }

    try:
        faq = soup.find('div', id='div_faq')
        for key, pattern in keyword_patterns.items():
            question = faq.find('h3', string=pattern)
            if question:
                answer = question.find_next('p').text
                if key in ['when_born', 'where_born']:
                    faq_data[key] = re.split(r'on | in ', answer)[-1].strip('.')
                elif key == 'height':
                    faq_data[key] = re.search(r'\d+-\d+', answer).group()
                elif key == 'weight':
                    faq_data[key] = re.search(r'\d+ lbs', answer).group().split()[0]
                elif key == 'superbowls':
                    faq_data[key] = re.search(r'\d+', answer) and re.search(r'\d+', answer).group() or '0'
                elif key in ['games_played', 'pass_yards', 'TD']:
                    faq_data[key] = re.search(r'\d+', answer.replace(',', '')).group()
                elif key == 'retire_year':
                    faq_data[key] = re.search(r'\d+', answer).group()
                elif key == 'nickname':
                    faq_data[key] = re.split(r' is a nickname| are nicknames', answer)[0]
                else:
                    faq_data[key] = answer
    except AttributeError as e:
        print(f"An error occurred in get_faq: {e}")
    return faq_data

# %%
def get_qb_summary_data(soup):
    qb_summary_data = {
        'years': '', 'games': '', 'games_started': '', 'qb_rec': '', 
        'pass_cmp': '', 'pass_att': '', 'pass_cmp_pct': '', 'pass_yds': '',
        'pass_td': '', 'pass_td_pct': '', 'pass_int': '', 'pass_int_pct': '',
        'pass_long': '', 'pass_yds_per_att': '', 'pass_adj_yds_per_att': '',
        'pass_yds_per_cmp': '', 'pass_yds_per_g': '', 'pass_rating': '',
        'pass_sacked': '', 'pass_sacked_yds': '', 'pass_sacked_pct': '',
        'pass_net_yds_per_att': '', 'pass_adj_net_yds_per_att': '',
        'comebacks': '', 'gwd': '', 'av': ''
    }
    
    try:
        # Locate the first row in the table footer
        summary_row = soup.find('tfoot').find('tr')

        # Extract the year information (first cell)
        qb_summary_data['years'] = summary_row.find('th', {'scope': 'row'}).text.strip()

        # Extract statistics from the row
        stats_cells = summary_row.find_all('td')
        qb_summary_data['games'] = stats_cells[1].text.strip()  # G
        qb_summary_data['games_started'] = stats_cells[2].text.strip()  # GS
        qb_summary_data['qb_rec'] = stats_cells[3].text.strip()  # QBrec
        qb_summary_data['pass_cmp'] = stats_cells[4].text.strip()  # Cmp
        qb_summary_data['pass_att'] = stats_cells[5].text.strip()  # Att
        qb_summary_data['pass_cmp_pct'] = stats_cells[6].text.strip()  # Cmp%
        qb_summary_data['pass_yds'] = stats_cells[7].text.strip()  # Yds
        qb_summary_data['pass_td'] = stats_cells[8].text.strip()  # TD
        qb_summary_data['pass_td_pct'] = stats_cells[9].text.strip()  # TD%
        qb_summary_data['pass_int'] = stats_cells[10].text.strip()  # Int
        qb_summary_data['pass_int_pct'] = stats_cells[11].text.strip()  # Int%
        qb_summary_data['pass_long'] = stats_cells[12].text.strip()  # Lng
        qb_summary_data['pass_yds_per_att'] = stats_cells[13].text.strip()  # Y/A
        qb_summary_data['pass_adj_yds_per_att'] = stats_cells[14].text.strip()  # AY/A
        qb_summary_data['pass_yds_per_cmp'] = stats_cells[15].text.strip()  # Y/C
        qb_summary_data['pass_yds_per_g'] = stats_cells[16].text.strip()  # Y/G
        qb_summary_data['pass_rating'] = stats_cells[17].text.strip()  # Rate
        qb_summary_data['pass_sacked'] = stats_cells[18].text.strip()  # Sk
        qb_summary_data['pass_sacked_yds'] = stats_cells[19].text.strip()  # Yds (sacked)
        qb_summary_data['pass_sacked_pct'] = stats_cells[20].text.strip()  # Sk%
        qb_summary_data['pass_net_yds_per_att'] = stats_cells[21].text.strip()  # NY/A
        qb_summary_data['pass_adj_net_yds_per_att'] = stats_cells[22].text.strip()  # ANY/A
        qb_summary_data['comebacks'] = stats_cells[23].text.strip()  # 4QC
        qb_summary_data['gwd'] = stats_cells[24].text.strip()  # GWD
        qb_summary_data['av'] = stats_cells[25].text.strip()  # AV

    except Exception as e:
        print(f"An error occurred while extracting from get_qb_summary_data: {e}")
    
    return qb_summary_data

# %%
import re

def create_url(name, page_num=0):
    '''Function to build the following URL from the name passed in:
    name_link = <first letter of last name> / <first four letters of last name><first two letters of first name>
    e.g., Kurt Warner --> W/WarnKu
    https://www.pro-football-reference.com/players/W/WarnKu00.htm
    '''
    
    try:
        # Clean up the name by removing apostrophes and periods
        name = name.replace("'", "").replace(".", "")
        pg_num = str(page_num).zfill(2)  # Format page number as two digits

        # Split name and assign first and last names
        name_parts = name.split()
        if len(name_parts) < 2:
            raise ValueError("Name must contain at least a first and last name")

        first_name = name_parts[0]
        last_name = ''.join(name_parts[1:])
        directory_letter = last_name[0].upper()  # First letter of last name as directory

        if len(last_name) < 4:
            raise ValueError("Last name must have at least 4 characters for URL creation")
        
        # Construct the name link
        name_link = f"{last_name[:4]}{first_name[:2]}"

        # Build the URL
        url = f"https://www.pro-football-reference.com/players/{directory_letter}/{name_link}{pg_num}.htm"
        return url

    except (IndexError, ValueError) as e:
        print(f"Error generating URL for '{name}': {e}")
        return "https://www.pro-football-reference.com/players/Unknown/Unknown00.htm"

# %%
# List to store each player's data as a dictionary
all_player_data = []

# Function to merge player data into a dictionary
def merge_player_data_dicts(name, qb_header_data, summary_stats, recognition_data, faq_data):
    player_data = {
        'name': name  # Add the player's name as a column for reference
    }
    player_data.update(qb_header_data)
    player_data.update(summary_stats)
    player_data.update(recognition_data)
    player_data.update(faq_data)
    player_data.update(qb_summary)

    all_player_data.append(player_data)

# %%
#  merge Values from 4 dictionaries (qb_header_data, summary_stats, recognition_data, faq_data) into single nested dictionary, 
#  with values flattened under one key (player's name).  (Not as sub-dictionaries).
                                      
# loop through each name, get the values from the sub-dictionaries, and populate 
# an entry in the quarterback_dict with their entry 

import requests
from bs4 import BeautifulSoup
import json

# function fetches a webpage, then checks the HTTP status code. If successful (200), it returns a BeautifulSoup object for parsing. 
#   Otherwise, it returns None and prints an error message. This will allow you to detect and handle failed page requests in your main loop.
def get_soup(url):
    print(f'\tFetching response for: {url}')
    response = requests.get(url)
    if response.status_code == 200:
        return BeautifulSoup(response.content, 'html.parser')
    elif response.status_code == 404:
        print(f"\tPage not found: {url}")
        return "not found"
    else:
        print(f"\tFailed to retrieve {url}. Status code: {response.status_code}")
        return None
    
# function attempts to verify if the page content includes the player's name. 
#   It first checks for a <script> tag containing JSON-LD data, which may contain a "name" field. 
#   If not found, it falls back to the <title> tag. 
#   If the player’s name is found in either, it returns True; otherwise, it returns False.
def validate_player_name(soup, player_name):
    json_ld_script = soup.find('script', type='application/ld+json')
    if json_ld_script:
        json_ld = json.loads(json_ld_script.string)
        if 'name' in json_ld and player_name.lower() in json_ld['name'].lower():
            return True
    title_tag = soup.find('title')
    if title_tag and player_name.lower() in title_tag.text.lower():
        return True
    return False

# %%
# Sample list of players
quarterback_dict = {}
quarterback_fails = []

qb_names = (qb_names_to_1969['Name'].tolist() 
            + qb_names_1970_9['Name'].tolist()
            + qb_names_1980_9['Name'].tolist()
            + qb_names_1990_9['Name'].tolist()
            + qb_names_2000_9['Name'].tolist()
            + qb_names_2010_9['Name'].tolist()
            + qb_names_2020_['Name'].tolist() )

print(qb_names)
print(len(qb_names))
# Out:
# ['Greg Cook', 'Marty Domres', 'Terry Hanratty', 'Bobby Douglass', 'Al Woodall', 'Onree Jackson', 'James Harris', 'Sam Havrilak', 'Larry Good', 'Sonny Wade', 'Bob Naponic', 'Alan Pastrana', 'Brian Dowling', 'Tim Carr', 'Bob Belden', 'Tom Boutwell', 'Ed Roseborough', 'Ed Hargett', "Buster O'Brien", 'Greg Landry', 'Eldridge Dickey', 'Gary Beban', 'Mike Livingston', 'Ken Stabler', 'Gary Davis', 'Billy Stevens', 'Ronnie South', 'Kim Hammond', 'Dewey Warren', 'John Schneider', 'Danny Holman', 'Greg Barton', 'Kim King', 'Jim Alcorn', 'Henry Johnson', 'Dan Darragh', 'Marlin Briscoe', 'Jim Haynie', 'Jeff Beaver', 'Jimmy Raye', 'Bob Lee', 'Steve Spurrier', 'Bob Griese', 'Don Horn', 'Bob David', 'Vidal Carlin', 'Terry Southall', 'Tim Jones', 'Virgil Carter', 'Rick Egloff', 'Corey Colehour', 'Bruce Matte', 'John Foruria', 'Steve Laub', 'Paul Krause', 'Dave Bennett', 'Ben Monroe', 'Jack Lentz', 'Paul Brothers', 'Bill Buckner', 'Bob Biletnikoff', 'Dan Talbott', 'Randy Johnson', 'Rick Norton', 'Gary Snook', 'Tim Van Galder', 'Ron Meyer', 'Jack White', 'Steve Sloan', 'Benjy Dial', 'Jim Ward', 'Jim LeClair', 'Mike Brundage', 'Benny Russell', 'Ken Lucas', 'Dave Neilson', 'Joe Namath', 'Craig Morton', 'Joe Namath', 'John Huarte', 'Bob Timberlake', 'Tommy Myers', 'John Huarte', 'Brig Owens', 'Jhn Hankinson', 'Gary Lane', 'Pat Screen', 'Ernie Kellerman', 'Dan Simrell', 'Steve Tensi', 'Tom LaFramboise', 'Karl Sweetan', 'Billy Guy Anderson', 'John Torok', 'Craig Fertig', 'George Wilson', 'George Haffner', 'Pete Beathard', 'Bill Munson', 'George Mira', 'Jack Concannon', 'Perry Lee Dunn', 'Billy Lothridge', 'Henry Schichtle', 'Dick Shiner', 'Gary Wood', 'Larry Rakestraw', 'Roger Staubach', 'Ron Smith', 'Bob Berry', 'Jerry Rhome', 'Jack Ankerson', 'Terry Baker', 'Dave Mathieson', 'Don Trull', 'Pete Liske', 'Bill Nelsen', 'Mike Taliaferro', 'Daryle Lamonica', 'Jim Turner', 'Roman Gabriel', 'Roman Gabriel', 'John Hadl', 'Sonny Gibbs', 'Eddie Wilson', 'John Furman', 'Glynn Griffing', 'Jim Bakken', 'Wilburn Hollis', 'Walt Rappold', 'Gale Weidner', 'Charlie Furlow', 'Mel Rideout', 'Joe Zuger', 'Bob Joiner', 'John Anabo', 'Ed Trancygier', 'Norm Snead', 'Fran Tarkenton', 'Jim Wright', 'Ron Miller', 'Dick Thornton', 'Jake Gibbs', 'Lowndes Shingler', 'Howard Dyer', 'Jack Moynihan', 'Don Jonas', 'Terry Nofsinger', 'Ben Charles', 'Mike McFarland', 'Mike Jones', 'George Izo', 'Richie Lucas', 'Warren Rabb', 'Charley Britt', 'Don Meredith', 'Jack Cummings', 'Dick Norman', 'Jacky Lee', 'Bobby Waters', 'Charley Johnson', 'Dave Grosz', 'Pete Hall', 'Jim Waldon', 'Dean Look', 'Randy Duncan', 'Don Allard', 'Dave Baker', 'Lee Grosscup', 'Buddy Humphrey', 'Richie Petitbon', 'Jim Grazione', 'Mitch Ogiego', 'Bob Ptacek', 'Dick Wood', 'Joe Kapp', 'Johnny Green', 'Frank Kremblas', 'Dick Jamieson', 'King Hill', 'Dan Nolan', 'Jim Ninowski', 'Jim Van Pelt', 'Frank Ryan', 'Al Jacks', 'Bob Brodhead', 'Mickey Trimarki', 'Ken (Model-T) Ford', 'Tom Forestal', 'John Brodie', 'Len Dawson', 'Milt Plum', 'Ronnie Knox', 'Bobby Cox', 'Sonny Jurgensen', 'Jimmy Harris', 'Chuck Curtis', 'Andy Nelson', 'Wade Mitchell', 'Corny Salvaterra', 'Jack Kemp', 'Kenny Ploen', 'Gene Cichowski', 'Ronnie Quillian', 'Bob Winters', 'Gary Glick', 'Earl Morrall', 'John Roach', 'Jerry Reichow', 'Em Lindbeck', 'John Polzer', 'Tom Spiers', 'George Herring', 'George Welsh', 'Bart Starr', 'Eagle Day', 'Eddie West', 'John Stephens', 'Pete Neft', 'Bobby Fox', 'Jerry Gustafson', 'Jim Miller', 'John Shearer', 'Bobby Lance', 'Rod Hermes', 'George Shaw', 'Ralph Guglielmi', 'Johnny Unitas', 'Johnny Borton', 'Charley Brackins', 'Pete Vann', 'Bobby Garrett', 'Lamar McHan', 'Cotton Davidson', 'Tom Yewcic', 'Ted Marchibroda', 'Zeke Bratkowski', 'Eddie Crowder', 'Rudy Bukich', 'Dale Samuels', 'Charlie Maloy', 'Bill Brehany', 'Billy Wade', 'Vito (Babe) Parilli', 'Harry Agganis', 'Don Klosterman', 'Al Dorow', 'Don Heinrich', 'Gary Kerkorian', 'Bob Williams', 'Y.A. Tittle', 'Adrian Burk', 'John (Model-T) Ford', 'Adrian Burk', 'Tob ...
# 1062

# %%
import time

# Iterate over the list of player names
for idx, name in enumerate(qb_names):
    # if idx > 3:  # Limiting the number of players for testing
    #     break
    print(f'\nPlayer ({idx}): {name}')
    valid_player = False

    # Attempt to find a valid page for the player
    for page_num in range(5):  # Check pages 00, 01, and 02
        time.sleep(6 + (page_num * 2))  # Incremental delay to avoid rate-limiting
        url = create_url(name, page_num)
        soup = get_soup(url)

        if soup == "not found":
            # Break out of the loop since we don't want to try other page numbers
            print(f"\tPage not found for {name} at {url}. Skipping further page attempts.")
            quarterback_fails.append(name)
            break

# Validate_player_name checks if page is the correct one. If it matches, data is gathered and added to main list.
        elif soup and validate_player_name(soup, name):
            print(f"** Successfully retrieved data for {name} at URL {page_num}: {url} **")
# Retrieve data sections
            qb_header_data = get_qb_header_data(soup)
            summary_stats = get_summary_stats(soup)
            recognition_data = get_recognition(soup)
            faq_data = get_faq(soup)
            qb_summary = get_qb_summary_data(soup)
# Merge player data and add to list
            merge_player_data_dicts(name, qb_header_data, summary_stats, recognition_data, faq_data)
            valid_player = True
            break
        else:
            print(f"\txx Failed to retrieve valid data for {name} with page number {str(page_num).zfill(2)} xx")
    
    if not valid_player:
        quarterback_fails.append(name)
        print(f"\tNo valid data found for {name} after checking all pages")

# After all players have been processed, pd.DataFrame(all_player_data) creates a single large DataFrame with all player data.
combined_df = pd.DataFrame(all_player_data)

# Display the combined DataFrame and list of failures
# print(combined_df)
print("Pages not found:", quarterback_fails)
# Out:
# Player (0): Greg Cook
# Fetching response for: https://www.pro-football-reference.com/players/C/CookGr00.htm
# 	Successfully retrieved data for Greg Cook at URL 0: https://www.pro-football-reference.com/players/C/CookGr00.htm
# Weighted Career AV: 10, Overall Rank: 8386
# C:\Users\black\AppData\Local\Temp\ipykernel_15692\3511687676.py:17: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   college_tag = soup.find('strong', text='College')
# C:\Users\black\AppData\Local\Temp\ipykernel_15692\3511687676.py:36: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   high_school_tag = soup.find('strong', text='High School')
# Player (1): Marty Domres
# Fetching response for: https://www.pro-football-reference.com/players/D/DomrMa00.htm
# 	Successfully retrieved data for Marty Domres at URL 0: https://www.pro-football-reference.com/players/D/DomrMa00.htm
# Weighted Career AV: 19, Overall Rank: 5811
# Player (2): Terry Hanratty
# Fetching response for: https://www.pro-football-reference.com/players/H/HanrTe00.htm
# 	Successfully retrieved data for Terry Hanratty at URL 0: https://www.pro-football-reference.com/players/H/HanrTe00.htm
# Weighted Career AV: 8, Overall Rank: 9197
# Player (3): Bobby Douglass
# Fetching response for: https://www.pro-football-reference.com/players/D/DougBo00.htm
# 	Successfully retrieved data for Bobby Douglass at URL 0: https://www.pro-football-reference.com/players/D/DougBo00.htm
# Weighted Career AV: 37, Overall Rank: 2916
# Player (4): Al Woodall
# Fetching response for: https://www.pro-football-reference.com/players/W/WoodAl00.htm
# 	Successfully retrieved data for Al Woodall at URL 0: https://www.pro-football-reference.com/players/W/WoodAl00.htm
# Weighted Career AV: 13, Overall Rank: 7362
# Player (5): Onree Jackson
# Fetching response for: https://www.pro-football-reference.com/players/J/JackOn00.htm
# 	Page not found: https://www.pro-football-reference.com/players/J/JackOn00.htm
# 	Page not found for Onree Jackson at https://www.pro-football-reference.com/players/J/JackOn00.htm. Skipping further page attempts.
# 	No valid data found for Onree Jackson after checking all pages
# Player (6): James Harris
# Fetching response for: https://www.pro-football-reference.com/players/H/HarrJa00.htm
# 	Failed to retrieve valid data for James Harris with page number 00
# Fetching response for: https://www.pro-football-reference.com/players/H/HarrJa01.htm
# 	Successfully retrieved data for James Harris at URL 1: https://www.pro-football-reference.com/players/H/HarrJa01.htm
# Weighted Career AV: 38, Overall Rank: 2793
# Player (7): Sam Havrilak
# Fetching response for: https://www.pro-football-reference.com/players/H/HavrSa00.htm
# 	Successfully retrieved data for Sam Havrilak at URL 0: https://www.pro-football-reference.com/players/H/HavrSa00.htm
# Weighted Career AV: 10, Overall Rank: 8386
# An error occurred while extracting summary data: list index out of range
# Player (8): Larry Good
# Fetching response for: https://www.pro-football-reference.com/players/G/GoodLa00.htm
# 	Page not found: https://www.pro-football-reference.com/players/G/GoodLa00.htm
# 	Page not found for Larry Good at https://www.pro-football-reference.com/players/G/GoodLa00.htm. Skipping further page attempts.
# 	No valid data found for Larry Good after checking all pages
# Player (9): Sonny Wade
# Fetching response for: https://www.pro-football-reference.com/players/W/WadeSo00.htm
# 	Page not found: https://www.pro-football-reference.com/players/W/WadeSo00.htm
# 	Page not found for Sonny Wade at https://www.pro-football-reference.com/players/W/WadeSo00.htm. Skipping further page attempts.
# 	No valid data found for Sonny Wade after checking all pages
# Player (10): Bob Naponic
# Fetching response for: https://www.pro-football-reference.com/players/N/NapoBo00.htm
# 	Successfully retrieved data for Bob Naponic at URL 0: https://www.pro-football-reference.com/players/N/NapoBo00.htm
# Weighted Career AV: 0, Overall Rank: 17659
# An error occurred: 'NoneType' object has no attribute 'group'
# Player (11): Alan Pastrana
# Fetching response for: https://www.pro-football-reference.com/players/P/PastAl00.htm
# 	Page not found: https://www.pro-football-reference.com/players/P/PastAl00.htm
# 	Page not found for Alan Pastrana at https://www.pro-football-reference.com/players/P/PastAl00.htm. Skipping further page attempts.
# 	No valid data found for Alan Pastrana after checking all pages
# Player (12): Brian Dowling
# Fetching response for: https://www.pro-football-reference.com/players/D/DowlBr00.htm
# 	Successfully retrieved data for Brian Dowling at URL 0: https://www.pro-football-reference.com/players/D/DowlBr00.htm
# Weighted Career AV: 1, Overall Rank: 15158
# Player (13): Tim Carr
# Fetching response for: https://www.pro-football-reference.com/players/C/CarrTi00.htm
# 	Page not found: https://www.pro-football-reference.com/players/C/CarrTi00.htm
# 	Page not found for Tim Carr at https://www.pro-football-reference.com/players/C/CarrTi00.htm. Skipping further page attempts.
# 	No valid data found for Tim Carr after checking all pages
# Player (14): Bob Belden
# Fetching response for: https://www.pro-football-reference.com/players/B/BeldBo00.htm
# 	Page not found: https://www.pro-football-reference.com/players/B/BeldBo00.htm
# 	Page not found for Bob Belden at https://www.pro-football-reference.com/players/B/BeldBo00.htm. Skipping further page attempts.
# 	No valid data found for Bob Belden after checking all pages
# Player (15): Tom Boutwell
# Fetching response for: https://www.pro-football-reference.com/players/B/BoutTo00.htm
# 	Failed to retrieve valid data for Tom Boutwell with page number 00
# Fetching response for: https://www.pro-football-reference.com/players/B/BoutTo01.htm
# 	Page not found: https://www.pro-football-reference.com/players/B/BoutTo01.htm
# 	Page not found for Tom Boutwell at https://www.pro-football-reference.com/players/B/BoutTo01.htm. Skipping further page attempts.
# 	No valid data found for Tom Boutwell after checking all pages
# Player (16): Ed Roseborough
# Fetching response for: https://www.pro-football-reference.com/players/R/RoseEd00.htm
# 	Page not found: https://www.pro-football-reference.com/players/R/RoseEd00.htm
# 	Page not found for Ed Roseborough at https://www.pro-football-reference.com/players/R/RoseEd00.htm. Skipping further page attempts.
# 	No valid data found for Ed Roseborough after checking all pages
# Player (17): Ed Hargett
# Fetching response for: https://www.pro-football-reference.com/players/H/HargEd00.htm
# 	Failed to retrieve valid data for Ed Hargett with page number 00
# Fetching response for: https://www.pro-football-reference.com/players/H/HargEd01.htm
# 	Page not found: https://www.pro-football-reference.com/players/H/HargEd01.htm
# 	Page not found for Ed Hargett at https://www.pro-football-reference.com/players/H/HargEd01.htm. Skipping further page attempts.
# 	No valid data found for Ed Hargett after checking all pages
# Player (18): Buster O'Brien
# Fetching response for: https://www.pro-football-reference.com/players/O/OBriBu00.htm
# 	Page not found: https://www.pro-football-reference.com/players/O/OBriBu00.htm
# 	Page not found for Buster O'Brien at https://www.pro-football-reference.com/players/O/OBriBu00.htm. Skipping further page attempts.
# 	No valid data found for Buster O'Brien after checking all pages
# Player (19): Greg Landry
# Fetching response for: https://www.pro-football-reference.com/players/L/LandGr00.htm
# 	Successfully retrieved data for Greg Landry at URL 0: https://www.pro-football-reference.com/players/L/LandGr00.htm
# Weighted Career AV: 80, Overall Rank: 424
# Player (20): Eldridge Dickey
# Fetching response for: https://www.pro-football-reference.com/players/D/DickEl00.htm
# 	Successfully retrieved data for Eldridge Dickey at URL 0: https://www.pro-football-reference.com/players/D/DickEl00.htm
# Weighted Career AV: 1, Overall Rank: 15158
# An error occurred while extracting summary data: list index out of range
# Player (21): Gary Beban
# Fetching response for: https://www.pro-football-reference.com/players/B/BebaGa00.htm
# 	Successfully retrieved data for Gary Beban at URL 0: https://www.pro-football-reference.com/players/B/BebaGa00.htm
# Weighted Career AV: 0, Overall Rank: 17659
# An error occurred while extracting summary data: list index out of range
# Player (22): Mike Livingston
# Fetching response for: https://www.pro-football-reference.com/players/L/LiviMi00.htm
# 	Successfully retrieved data for Mike Livingston at URL 0: https://www.pro-football-reference.com/players/L/LiviMi00.htm
# Weighted Career AV: 42, Overall Rank: 2388
# Player (23): Ken Stabler
# Fetching response for: https://www.pro-football-reference.com/players/S/StabKe00.htm
# 	Successfully retrieved data for Ken Stabler at URL 0: https://www.pro-football-reference.com/players/S/StabKe00.htm
# Weighted Career AV: 93, Overall Rank: 234
# Player (24): Gary Davis
# Fetching response for: https://www.pro-football-reference.com/players/D/DaviGa00.htm
# 	Successfully retrieved data for Gary Davis at URL 0: https://www.pro-football-reference.com/players/D/DaviGa00.htm
# Weighted Career AV: 23, Overall Rank: 4988
# An error occurred while extracting summary data: list index out of range
# Player (25): Billy Stevens
# Fetching response for: https://www.pro-football-reference.com/players/S/StevBi00.htm
# 	Successfully retrieved data for Billy Stevens at URL 0: https://www.pro-football-reference.com/players/S/StevBi00.htm
# Weighted Career AV: 0, Overall Rank: 17659
# An error occurred: 'NoneType' object has no attribute 'group'
# Player (26): Ronnie South
# Fetching response for: https://www.pro-football-reference.com/players/S/SoutRo00.htm
# 	Failed to retrieve valid data for Ronnie South with page number 00
# Fetching response for: https://www.pro-football-reference.com/players/S/SoutRo01.htm
# 	Page not found: https://www.pro-football-reference.com/players/S/SoutRo01.htm
# 	Page not found for Ronnie South at https://www.pro-football-reference.com/players/S/SoutRo01.htm. Skipping further page attempts.
# 	No valid data found for Ronnie South after checking all pages
# Player (27): Kim Hammond
# Fetching response for: https://www.pro-football-reference.com/players/H/HammKi00.htm
# 	Successfully retrieved data for Kim Hammond at URL 0: https://www.pro-football-reference.com/players/H/HammKi00.htm
# Weighted Career AV: 0, Overall Rank: 17659
# An error occurred: 'NoneType' object has no attribute 'group'
# Player (28): Dewey Warren
# Fetching response for: https://www.pro-football-reference.com/players/W/WarrDe00.htm
# 	Successfully retrieved data for Dewey Warren at URL 0: https://www.pro-football-reference.com/players/W/WarrDe00.htm
# Weighted Career AV: 2, Overall Rank: 13593
# Player (29): John Schneider
# Fetching response for: https://www.pro-football-reference.com/players/S/SchnJo00.htm
# 	Page not found: https://www.pro-football-reference.com/players/S/SchnJo00.htm
# 	Page not found for John Schneider at https://www.pro-football-reference.com/players/S/SchnJo00.htm. Skipping further page attempts.
# 	No valid data found for John Schneider after checking all pages
# Player (30): Danny Holman
# Fetching response for: https://www.pro-football-reference.com/players/H/HolmDa00.htm
# 	Failed to retrieve valid data for Danny Holman with page number 00
# Fetching response for: https://www.pro-football-reference.com/players/H/HolmDa01.htm
# 	Failed to retrieve valid data for Danny Holman with page number 01
# Fetching response for: https://www.pro-football-reference.com/players/H/HolmDa02.htm
# 	Page not found: https://www.pro-football-reference.com/players/H/HolmDa02.htm
# 	Page not found for Danny Holman at https://www.pro-football-reference.com/players/H/HolmDa02.htm. Skipping further page attempts.
# 	No valid data found for Danny Holman after checking all pages
# Player (31): Greg Barton
# Fetching response for: https://www.pro-football-reference.com/players/B/BartGr00.htm
# 	Failed to retrieve valid data for Greg Barton with page number 00
# Fetching response for: https://www.pro-football-reference.com/players/B/BartGr01.htm
# 	Page not found: https://www.pro-football-reference.com/players/B/BartGr01.htm
# 	Page not found for Greg Barton at https://www.pro-football-reference.com/players/B/BartGr01.htm. Skipping further page attempts.
# 	No valid data found for Greg Barton after checking all pages
# Player (32): Kim King
# Fetching response for: https://www.pro-football-reference.com/players/K/KingKi00.htm
# 	Page not found: https://www.pro-football-reference.com/players/K/KingKi00.htm
# 	Page not found for Kim King at https://www.pro-football-reference.com/players/K/KingKi00.htm. Skipping further page attempts.
# 	No valid data found for Kim King after checking all pages
# Player (33): Jim Alcorn
# Fetching response for: https://www.pro-football-reference.com/players/A/AlcoJi00.htm
# 	Page not found: https://www.pro-football-reference.com/players/A/AlcoJi00.htm
# 	Page not found for Jim Alcorn at https://www.pro-football-reference.com/players/A/AlcoJi00.htm. Skipping further page attempts.
# 	No valid data found for Jim Alcorn after checking all pages
# Player (34): Henry Johnson
# Fetching response for: https://www.pro-football-reference.com/players/J/JohnHe00.htm
# 	Page not found: https://www.pro-football-reference.com/players/J/JohnHe00.htm
# 	Page not found for Henry Johnson at https://www.pro-football-reference.com/players/J/JohnHe00.htm. Skipping further page attempts.
# 	No valid data found for Henry Johnson after checking all pages
# Player (35): Dan Darragh
# Fetching response for: https://www.pro-football-reference.com/players/D/DarrDa00.htm
# 	Successfully retrieved data for Dan Darragh at URL 0: https://www.pro-football-reference.com/players/D/DarrDa00.htm
# Weighted Career AV: 2, Overall Rank: 27829
# Player (36): Marlin Briscoe
# Fetching response for: https://www.pro-football-reference.com/players/B/BrisMa00.htm
# 	Successfully retrieved data for Marlin Briscoe at URL 0: https://www.pro-football-reference.com/players/B/BrisMa00.htm
# Weighted Career AV: 42, Overall Rank: 2388
# Player (37): Jim Haynie
# Fetching response for: https://www.pro-football-reference.com/players/H/HaynJi00.htm
# 	Page not found: https://www.pro-football-reference.com/players/H/HaynJi00.htm
# 	Page not found for Jim Haynie at https://www.pro-football-reference.com/players/H/HaynJi00.htm. Skipping further page attempts.
# 	No valid data found for Jim Haynie after checking all pages
# Player (38): Jeff Beaver
# Fetching response for: https://www.pro-football-reference.com/players/B/BeavJe00.htm
# 	Page not found: https://www.pro-football-reference.com/players/B/BeavJe00.htm
# 	Page not found for Jeff Beaver at https://www.pro-football-reference.com/players/B/BeavJe00.htm. Skipping further page attempts.
# 	No valid data found for Jeff Beaver after checking all pages
# Player (39): Jimmy Raye
# Fetching response for: https://www.pro-football-reference.com/players/R/RayeJi00.htm
# 	Page not found: https://www.pro-football-reference.com/players/R/RayeJi00.htm
# 	Page not found for Jimmy Raye at https://www.pro-football-reference.com/players/R/RayeJi00.htm. Skipping further page attempts.
# 	No valid data found for Jimmy Raye after checking all pages
# Player (40): Bob Lee
# Error generating URL for 'Bob Lee': Last name must have at least 4 characters for URL creation
# Fetching response for: https://www.pro-football-reference.com/players/Unknown/Unknown00.htm
# 	Page not found: https://www.pro-football-reference.com/players/Unknown/Unknown00.htm
# 	Page not found for Bob Lee at https://www.pro-football-reference.com/players/Unknown/Unknown00.htm. Skipping further page attempts.
# 	No valid data found for Bob Lee after checking all pages
# Player (41): Steve Spurrier
# Fetching response for: https://www.pro-football-reference.com/players/S/SpurSt00.htm
# 	Successfully retrieved data for Steve Spurrier at URL 0: https://www.pro-football-reference.com/players/S/SpurSt00.htm
# Weighted Career AV: 26, Overall Rank: 4460
# Player (42): Bob Griese
# Fetching response for: https://www.pro-football-reference.com/players/G/GrieBo00.htm
# 	Successfully retrieved data for Bob Griese at URL 0: https://www.pro-football-reference.com/players/G/GrieBo00.htm
# Weighted Career AV: 104, Overall Rank: 103
# Player (43): Don Horn
# Fetching response for: https://www.pro-football-reference.com/players/H/HornDo00.htm
# 	Successfully retrieved data for Don Horn at URL 0: https://www.pro-football-reference.com/players/H/HornDo00.htm
# Weighted Career AV: 10, Overall Rank: 8386
# Player (44): Bob David
# Fetching response for: https://www.pro-football-reference.com/players/D/DaviBo00.htm
# 	Failed to retrieve valid data for Bob David with page number 00
# Fetching response for: https://www.pro-football-reference.com/players/D/DaviBo01.htm
# 	Page not found: https://www.pro-football-reference.com/players/D/DaviBo01.htm
# 	Page not found for Bob David at https://www.pro-football-reference.com/players/D/DaviBo01.htm. Skipping further page attempts.
# 	No valid data found for Bob David after checking all pages
# Player (45): Vidal Carlin
# Fetching response for: https://www.pro-football-reference.com/players/C/CarlVi00.htm
# 	Page not found: https://www.pro-football-reference.com/players/C/CarlVi00.htm
# 	Page not found for Vidal Carlin at https://www.pro-football-reference.com/players/C/CarlVi00.htm. Skipping further page attempts.
# 	No valid data found for Vidal Carlin after checking all pages
# Player (46): Terry Southall
# Fetching response for: https://www.pro-football-reference.com/players/S/SoutTe00.htm
# 	Page not found: https://www.pro-football-reference.com/players/S/SoutTe00.htm
# 	Page not found for Terry Southall at https://www.pro-football-reference.com/players/S/SoutTe00.htm. Skipping further page attempts.
# 	No valid data found for Terry Southall after checking all pages
# Player (47): Tim Jones
# Fetching response for: https://www.pro-football-reference.com/players/J/JoneTi00.htm
# 	Successfully retrieved data for Tim Jones at URL 0: https://www.pro-football-reference.com/players/J/JoneTi00.htm
# Weighted Career AV: 1, Overall Rank: 15158
# Player (48): Virgil Carter
# Fetching response for: https://www.pro-football-reference.com/players/C/CartVi00.htm
# 	Successfully retrieved data for Virgil Carter at URL 0: https://www.pro-football-reference.com/players/C/CartVi00.htm
# Weighted Career AV: 26, Overall Rank: 4460
# Player (49): Rick Egloff
# Fetching response for: https://www.pro-football-reference.com/players/E/EgloRi00.htm
# 	Page not found: https://www.pro-football-reference.com/players/E/EgloRi00.htm
# 	Page not found for Rick Egloff at https://www.pro-football-reference.com/players/E/EgloRi00.htm. Skipping further page attempts.
# 	No valid data found for Rick Egloff after checking all pages
# Player (50): Corey Colehour
# Fetching response for: https://www.pro-football-reference.com/players/C/ColeCo00.htm
# 	Failed to retrieve valid data for Corey Colehour with page number 00
# Fetching response for: https://www.pro-football-reference.com/players/C/ColeCo01.htm
# 	Page not found: https://www.pro-football-reference.com/players/C/ColeCo01.htm
# 	Page not found for Corey Colehour at https://www.pro-football-reference.com/players/C/ColeCo01.htm. Skipping further page attempts.
# 	No valid data found for Corey Colehour after checking all pages
# Player (51): Bruce Matte
# Fetching response for: https://www.pro-football-reference.com/players/M/MattBr00.htm
# 	Failed to retrieve valid data for Bruce Matte with page number 00
# Fetching response for: https://www.pro-football-reference.com/players/M/MattBr01.htm
# 	Page not found: https://www.pro-football-reference.com/players/M/MattBr01.htm
# 	Page not found for Bruce Matte at https://www.pro-football-reference.com/players/M/MattBr01.htm. Skipping further page attempts.
# 	No valid data found for Bruce Matte after checking all pages
# Player (52): John Foruria
# Fetching response for: https://www.pro-football-reference.com/players/F/ForuJo00.htm
# 	Page not found: https://www.pro-football-reference.com/players/F/ForuJo00.htm
# 	Page not found for John Foruria at https://www.pro-football-reference.com/players/F/ForuJo00.htm. Skipping further page attempts.
# 	No valid data found for John Foruria after checking all pages
# Player (53): Steve Laub
# Fetching response for: https://www.pro-football-reference.com/players/L/LaubSt00.htm
# 	Page not found: https://www.pro-football-reference.com/players/L/LaubSt00.htm
# 	Page not found for Steve Laub at https://www.pro-football-reference.com/players/L/LaubSt00.htm. Skipping further page attempts.
# 	No valid data found for Steve Laub after checking all pages
# Player (54): Paul Krause
# Fetching response for: https://www.pro-football-reference.com/players/K/KrauPa00.htm
# 	Successfully retrieved data for Paul Krause at URL 0: https://www.pro-football-reference.com/players/K/KrauPa00.htm
# Weighted Career AV: 119, Overall Rank: 47
# An error occurred while extracting summary data: list index out of range
# Player (55): Dave Bennett
# Fetching response for: https://www.pro-football-reference.com/players/B/BennDa00.htm
# 	Page not found: https://www.pro-football-reference.com/players/B/BennDa00.htm
# 	Page not found for Dave Bennett at https://www.pro-football-reference.com/players/B/BennDa00.htm. Skipping further page attempts.
# 	No valid data found for Dave Bennett after checking all pages
# Player (56): Ben Monroe
# Fetching response for: https://www.pro-football-reference.com/players/M/MonrBe00.htm
# 	Page not found: https://www.pro-football-reference.com/players/M/MonrBe00.htm
# 	Page not found for Ben Monroe at https://www.pro-football-reference.com/players/M/MonrBe00.htm. Skipping further page attempts.
# 	No valid data found for Ben Monroe after checking all pages
# Player (57): Jack Lentz
# Fetching response for: https://www.pro-football-reference.com/players/L/LentJa00.htm
# 	Page not found: https://www.pro-football-reference.com/players/L/LentJa00.htm
# 	Page not found for Jack Lentz at https://www.pro-football-reference.com/players/L/LentJa00.htm. Skipping further page attempts.
# 	No valid data found for Jack Lentz after checking all pages
# Player (58): Paul Brothers
# Fetching response for: https://www.pro-football-reference.com/players/B/BrotPa00.htm
# 	Page not found: https://www.pro-football-reference.com/players/B/BrotPa00.htm
# 	Page not found for Paul Brothers at https://www.pro-football-reference.com/players/B/BrotPa00.htm. Skipping further page attempts.
# 	No valid data found for Paul Brothers after checking all pages
# Player (59): Bill Buckner
# Fetching response for: https://www.pro-football-reference.com/players/B/BuckBi00.htm
# 	Page not found: https://www.pro-football-reference.com/players/B/BuckBi00.htm
# 	Page not found for Bill Buckner at https://www.pro-football-reference.com/players/B/BuckBi00.htm. Skipping further page attempts.
# 	No valid data found for Bill Buckner after checking all pages
# Player (60): Bob Biletnikoff
# Fetching response for: https://www.pro-football-reference.com/players/B/BileBo00.htm
# 	Page not found: https://www.pro-football-reference.com/players/B/BileBo00.htm
# 	Page not found for Bob Biletnikoff at https://www.pro-football-reference.com/players/B/BileBo00.htm. Skipping further page attempts.
# 	No valid data found for Bob Biletnikoff after checking all pages
# Player (61): Dan Talbott
# Fetching response for: https://www.pro-football-reference.com/players/T/TalbDa00.htm
# 	Page not found: https://www.pro-football-reference.com/players/T/TalbDa00.htm
# 	Page not found for Dan Talbott at https://www.pro-football-reference.com/players/T/TalbDa00.htm. Skipping further page attempts.
# 	No valid data found for Dan Talbott after checking all pages
# Player (62): Randy Johnson
# Fetching response for: https://www.pro-football-reference.com/players/J/JohnRa00.htm
# 	Successfully retrieved data for Randy Johnson at URL 0: https://www.pro-football-reference.com/players/J/JohnRa00.htm
# Weighted Career AV: 24, Overall Rank: 4805
# Player (63): Rick Norton
# Fetching response for: https://www.pro-football-reference.com/players/N/NortRi00.htm
# 	Successfully retrieved data for Rick Norton at URL 0: https://www.pro-football-reference.com/players/N/NortRi00.htm
# Weighted Career AV: 6, Overall Rank: 10278
# Player (64): Gary Snook
# Fetching response for: https://www.pro-football-reference.com/players/S/SnooGa00.htm
# 	Page not found: https://www.pro-football-reference.com/players/S/SnooGa00.htm
# 	Page not found for Gary Snook at https://www.pro-football-reference.com/players/S/SnooGa00.htm. Skipping further page attempts.
# 	No valid data found for Gary Snook after checking all pages
# Player (65): Tim Van Galder
# Fetching response for: https://www.pro-football-reference.com/players/V/VanGTi00.htm
# 	Successfully retrieved data for Tim Van Galder at URL 0: https://www.pro-football-reference.com/players/V/VanGTi00.htm
# Weighted Career AV: 2, Overall Rank: 13593
# Player (66): Ron Meyer
# Fetching response for: https://www.pro-football-reference.com/players/M/MeyeRo00.htm
# 	Successfully retrieved data for Ron Meyer at URL 0: https://www.pro-football-reference.com/players/M/MeyeRo00.htm
# Weighted Career AV: 0, Overall Rank: 17659
# An error occurred: 'NoneType' object has no attribute 'group'
# Player (67): Jack White
# Fetching response for: https://www.pro-football-reference.com/players/W/WhitJa00.htm
# 	Failed to retrieve valid data for Jack White with page number 00
# Fetching response for: https://www.pro-football-reference.com/players/W/WhitJa01.htm
# 	Failed to retrieve valid data for Jack White with page number 01
# Fetching response for: https://www.pro-football-reference.com/players/W/WhitJa02.htm
# 	Failed to retrieve valid data for Jack White with page number 02
# Fetching response for: https://www.pro-football-reference.com/players/W/WhitJa03.htm
# 	Failed to retrieve valid data for Jack White with page number 03
# Fetching response for: https://www.pro-football-reference.com/players/W/WhitJa04.htm
# 	Failed to retrieve valid data for Jack White with page number 04
# 	No valid data found for Jack White after checking all pages
# Player (68): Steve Sloan
# Fetching response for: https://www.pro-football-reference.com/players/S/SloaSt00.htm
# 	Successfully retrieved data for Steve Sloan at URL 0: https://www.pro-football-reference.com/players/S/SloaSt00.htm
# Weighted Career AV: 0, Overall Rank: 17659
# An error occurred: 'NoneType' object has no attribute 'group'
# Player (69): Benjy Dial
# Fetching response for: https://www.pro-football-reference.com/players/D/DialBe00.htm
# 	Successfully retrieved data for Benjy Dial at URL 0: https://www.pro-football-reference.com/players/D/DialBe00.htm
# Weighted Career AV: 0, Overall Rank: 17659
# An error occurred: 'NoneType' object has no attribute 'group'
# Player (70): Jim Ward
# Fetching response for: https://www.pro-football-reference.com/players/W/WardJi00.htm
# 	Successfully retrieved data for Jim Ward at URL 0: https://www.pro-football-reference.com/players/W/WardJi00.htm
# Weighted Career AV: 1, Overall Rank: 15158
# Player (71): Jim LeClair
# Fetching response for: https://www.pro-football-reference.com/players/L/LeClJi00.htm
# 	Successfully retrieved data for Jim LeClair at URL 0: https://www.pro-football-reference.com/players/L/LeClJi00.htm
# Weighted Career AV: 2, Overall Rank: 13593
# Player (72): Mike Brundage
# Fetching response for: https://www.pro-football-reference.com/players/B/BrunMi00.htm
# 	Failed to retrieve valid data for Mike Brundage with page number 00
# Fetching response for: https://www.pro-football-reference.com/players/B/BrunMi01.htm
# 	Page not found: https://www.pro-football-reference.com/players/B/BrunMi01.htm
# 	Page not found for Mike Brundage at https://www.pro-football-reference.com/players/B/BrunMi01.htm. Skipping further page attempts.
# 	No valid data found for Mike Brundage after checking all pages
# Player (73): Benny Russell
# Fetching response for: https://www.pro-football-reference.com/players/R/RussBe00.htm
# 	Successfully retrieved data for Benny Russell at URL 0: https://www.pro-football-reference.com/players/R/RussBe00.htm
# Weighted Career AV: 0, Overall Rank: 17659
# An error occurred: 'NoneType' object has no attribute 'group'
# An error occurred while extracting summary data: list index out of range
# Player (74): Ken Lucas
# Fetching response for: https://www.pro-football-reference.com/players/L/LucaKe00.htm
# 	Failed to retrieve valid data for Ken Lucas with page number 00
# Fetching response for: https://www.pro-football-reference.com/players/L/LucaKe01.htm
# 	Page not found: https://www.pro-football-reference.com/players/L/LucaKe01.htm
# 	Page not found for Ken Lucas at https://www.pro-football-reference.com/players/L/LucaKe01.htm. Skipping further page attempts.
# 	No valid data found for Ken Lucas after checking all pages
# Player (75): Dave Neilson
# Fetching response for: https://www.pro-football-reference.com/players/N/NeilDa00.htm
# 	Page not found: https://www.pro-football-reference.com/players/N/NeilDa00.htm
# 	Page not found for Dave Neilson at https://www.pro-football-reference.com/players/N/NeilDa00.htm. Skipping further page attempts.
# 	No valid data found for Dave Neilson after checking all pages
# Player (76): Joe Namath
# Fetching response for: https://www.pro-football-reference.com/players/N/NamaJo00.htm
# 	Successfully retrieved data for Joe Namath at URL 0: https://www.pro-football-reference.com/players/N/NamaJo00.htm
# Weighted Career AV: 94, Overall Rank: 222
# Player (77): Craig Morton
# Fetching response for: https://www.pro-football-reference.com/players/M/MortCr00.htm
# 	Successfully retrieved data for Craig Morton at URL 0: https://www.pro-football-reference.com/players/M/MortCr00.htm
# Weighted Career AV: 84, Overall Rank: 354
# Player (78): Joe Namath
# Fetching response for: https://www.pro-football-reference.com/players/N/NamaJo00.htm
# 	Successfully retrieved data for Joe Namath at URL 0: https://www.pro-football-reference.com/players/N/NamaJo00.htm
# Weighted Career AV: 94, Overall Rank: 222
# Player (79): John Huarte
# Fetching response for: https://www.pro-football-reference.com/players/H/HuarJo00.htm
# 	Successfully retrieved data for John Huarte at URL 0: https://www.pro-football-reference.com/players/H/HuarJo00.htm
# Weighted Career AV: 1, Overall Rank: 15158
# Player (80): Bob Timberlake
# Fetching response for: https://www.pro-football-reference.com/players/T/TimbBo00.htm
# 	Page not found: https://www.pro-football-reference.com/players/T/TimbBo00.htm
# 	Page not found for Bob Timberlake at https://www.pro-football-reference.com/players/T/TimbBo00.htm. Skipping further page attempts.
# 	No valid data found for Bob Timberlake after checking all pages
# Player (81): Tommy Myers
# Fetching response for: https://www.pro-football-reference.com/players/M/MyerTo00.htm
# 	Failed to retrieve valid data for Tommy Myers with page number 00
# Fetching response for: https://www.pro-football-reference.com/players/M/MyerTo01.htm
# 	Failed to retrieve valid data for Tommy Myers with page number 01
# Fetching response for: https://www.pro-football-reference.com/players/M/MyerTo02.htm
# 	Page not found: https://www.pro-football-reference.com/players/M/MyerTo02.htm
# 	Page not found for Tommy Myers at https://www.pro-football-reference.com/players/M/MyerTo02.htm. Skipping further page attempts.
# 	No valid data found for Tommy Myers after checking all pages
# Player (82): John Huarte
# Fetching response for: https://www.pro-football-reference.com/players/H/HuarJo00.htm
# 	Successfully retrieved data for John Huarte at URL 0: https://www.pro-football-reference.com/players/H/HuarJo00.htm
# Weighted Career AV: 1, Overall Rank: 15158
# Player (83): Brig Owens
# Fetching response for: https://www.pro-football-reference.com/players/O/OwenBr00.htm
# 	Page not found: https://www.pro-football-reference.com/players/O/OwenBr00.htm
# 	Page not found for Brig Owens at https://www.pro-football-reference.com/players/O/OwenBr00.htm. Skipping further page attempts.
# 	No valid data found for Brig Owens after checking all pages
# Player (84): Jhn Hankinson
# Fetching response for: https://www.pro-football-reference.com/players/H/HankJh00.htm
# 	Page not found: https://www.pro-football-reference.com/players/H/HankJh00.htm
# 	Page not found for Jhn Hankinson at https://www.pro-football-reference.com/players/H/HankJh00.htm. Skipping further page attempts.
# 	No valid data found for Jhn Hankinson after checking all pages
# Player (85): Gary Lane
# Fetching response for: https://www.pro-football-reference.com/players/L/LaneGa00.htm
# 	Successfully retrieved data for Gary Lane at URL 0: https://www.pro-football-reference.com/players/L/LaneGa00.htm
# Weighted Career AV: 1, Overall Rank: 15158
# Player (86): Pat Screen
# Fetching response for: https://www.pro-football-reference.com/players/S/ScrePa00.htm
# 	Page not found: https://www.pro-football-reference.com/players/S/ScrePa00.htm
# 	Page not found for Pat Screen at https://www.pro-football-reference.com/players/S/ScrePa00.htm. Skipping further page attempts.
# 	No valid data found for Pat Screen after checking all pages
# Player (87): Ernie Kellerman
# Fetching response for: https://www.pro-football-reference.com/players/K/KellEr00.htm
# 	Successfully retrieved data for Ernie Kellerman at URL 0: https://www.pro-football-reference.com/players/K/KellEr00.htm
# Weighted Career AV: 38, Overall Rank: 2793
# An error occurred while extracting summary data: list index out of range
# Player (88): Dan Simrell
# Fetching response for: https://www.pro-football-reference.com/players/S/SimrDa00.htm
# 	Page not found: https://www.pro-football-reference.com/players/S/SimrDa00.htm
# 	Page not found for Dan Simrell at https://www.pro-football-reference.com/players/S/SimrDa00.htm. Skipping further page attempts.
# 	No valid data found for Dan Simrell after checking all pages
# Player (89): Steve Tensi
# Fetching response for: https://www.pro-football-reference.com/players/T/TensSt00.htm
# 	Successfully retrieved data for Steve Tensi at URL 0: https://www.pro-football-reference.com/players/T/TensSt00.htm
# Weighted Career AV: 20, Overall Rank: 5605
# Player (90): Tom LaFramboise
# Fetching response for: https://www.pro-football-reference.com/players/L/LaFrTo00.htm
# 	Page not found: https://www.pro-football-reference.com/players/L/LaFrTo00.htm
# 	Page not found for Tom LaFramboise at https://www.pro-football-reference.com/players/L/LaFrTo00.htm. Skipping further page attempts.
# 	No valid data found for Tom LaFramboise after checking all pages
# Player (91): Karl Sweetan
# Fetching response for: https://www.pro-football-reference.com/players/S/SweeKa00.htm
# 	Successfully retrieved data for Karl Sweetan at URL 0: https://www.pro-football-reference.com/players/S/SweeKa00.htm
# Weighted Career AV: 9, Overall Rank: 8769
# Player (92): Billy Guy Anderson
# Fetching response for: https://www.pro-football-reference.com/players/G/GuyABi00.htm
# 	Page not found: https://www.pro-football-reference.com/players/G/GuyABi00.htm
# 	Page not found for Billy Guy Anderson at https://www.pro-football-reference.com/players/G/GuyABi00.htm. Skipping further page attempts.
# 	No valid data found for Billy Guy Anderson after checking all pages
# Player (93): John Torok
# Fetching response for: https://www.pro-football-reference.com/players/T/ToroJo00.htm
# 	Page not found: https://www.pro-football-reference.com/players/T/ToroJo00.htm
# 	Page not found for John Torok at https://www.pro-football-reference.com/players/T/ToroJo00.htm. Skipping further page attempts.
# 	No valid data found for John Torok after checking all pages
# Player (94): Craig Fertig
# Fetching response for: https://www.pro-football-reference.com/players/F/FertCr00.htm
# 	Page not found: https://www.pro-football-reference.com/players/F/FertCr00.htm
# 	Page not found for Craig Fertig at https://www.pro-football-reference.com/players/F/FertCr00.htm. Skipping further page attempts.
# 	No valid data found for Craig Fertig after checking all pages
# Player (95): George Wilson
# Fetching response for: https://www.pro-football-reference.com/players/W/WilsGe00.htm
# 	Successfully retrieved data for George Wilson at URL 0: https://www.pro-football-reference.com/players/W/WilsGe00.htm
# Weighted Career AV: 5, Overall Rank: 10956
# Player (96): George Haffner
# Fetching response for: https://www.pro-football-reference.com/players/H/HaffGe00.htm
# 	Page not found: https://www.pro-football-reference.com/players/H/HaffGe00.htm
# 	Page not found for George Haffner at https://www.pro-football-reference.com/players/H/HaffGe00.htm. Skipping further page attempts.
# 	No valid data found for George Haffner after checking all pages
# Player (97): Pete Beathard
# Fetching response for: https://www.pro-football-reference.com/players/B/BeatPe00.htm
# 	Successfully retrieved data for Pete Beathard at URL 0: https://www.pro-football-reference.com/players/B/BeatPe00.htm
# Weighted Career AV: 26, Overall Rank: 4460
# Player (98): Bill Munson
# Fetching response for: https://www.pro-football-reference.com/players/M/MunsBi00.htm
# 	Successfully retrieved data for Bill Munson at URL 0: https://www.pro-football-reference.com/players/M/MunsBi00.htm
# Weighted Career AV: 48, Overall Rank: 1862
# Player (99): George Mira
# Fetching response for: https://www.pro-football-reference.com/players/M/MiraGe00.htm
# 	Successfully retrieved data for George Mira at URL 0: https://www.pro-football-reference.com/players/M/MiraGe00.htm
# Weighted Career AV: 10, Overall Rank: 8386
# Player (100): Jack Concannon
# Fetching response for: https://www.pro-football-reference.com/players/C/ConcJa00.htm
# 	Successfully retrieved data for Jack Concannon at URL 0: https://www.pro-football-reference.com/players/C/ConcJa00.htm
# Weighted Career AV: 26, Overall Rank: 4460
# Player (101): Perry Lee Dunn
# Fetching response for: https://www.pro-football-reference.com/players/L/LeeDPe00.htm
# 	Page not found: https://www.pro-football-reference.com/players/L/LeeDPe00.htm
# 	Page not found for Perry Lee Dunn at https://www.pro-football-reference.com/players/L/LeeDPe00.htm. Skipping further page attempts.
# 	No valid data found for Perry Lee Dunn after checking all pages
# Player (102): Billy Lothridge
# Fetching response for: https://www.pro-football-reference.com/players/L/LothBi00.htm
# 	Page not found: https://www.pro-football-reference.com/players/L/LothBi00.htm
# 	Page not found for Billy Lothridge at https://www.pro-football-reference.com/players/L/LothBi00.htm. Skipping further page attempts.
# 	No valid data found for Billy Lothridge after checking all pages
# Player (103): Henry Schichtle
# Fetching response for: https://www.pro-football-reference.com/players/S/SchiHe00.htm
# 	Page not found: https://www.pro-football-reference.com/players/S/SchiHe00.htm
# 	Page not found for Henry Schichtle at https://www.pro-football-reference.com/players/S/SchiHe00.htm. Skipping further page attempts.
# 	No valid data found for Henry Schichtle after checking all pages
# Player (104): Dick Shiner
# Fetching response for: https://www.pro-football-reference.com/players/S/ShinDi00.htm
# 	Successfully retrieved data for Dick Shiner at URL 0: https://www.pro-football-reference.com/players/S/ShinDi00.htm
# Weighted Career AV: 17, Overall Rank: 6286
# Player (105): Gary Wood
# Fetching response for: https://www.pro-football-reference.com/players/W/WoodGa00.htm
# 	Successfully retrieved data for Gary Wood at URL 0: https://www.pro-football-reference.com/players/W/WoodGa00.htm
# Weighted Career AV: 10, Overall Rank: 8386
# Player (106): Larry Rakestraw
# Fetching response for: https://www.pro-football-reference.com/players/R/RakeLa00.htm
# 	Successfully retrieved data for Larry Rakestraw at URL 0: https://www.pro-football-reference.com/players/R/RakeLa00.htm
# Weighted Career AV: 3, Overall Rank: 12506
# Player (107): Roger Staubach
# Fetching response for: https://www.pro-football-reference.com/players/S/StauRo00.htm
# 	Successfully retrieved data for Roger Staubach at URL 0: https://www.pro-football-reference.com/players/S/StauRo00.htm
# Weighted Career AV: 104, Overall Rank: 103
# Player (108): Ron Smith
# Fetching response for: https://www.pro-football-reference.com/players/S/SmitRo00.htm
# 	Failed to retrieve valid data for Ron Smith with page number 00
# Fetching response for: https://www.pro-football-reference.com/players/S/SmitRo01.htm
# 	Failed to retrieve valid data for Ron Smith with page number 01
# Fetching response for: https://www.pro-football-reference.com/players/S/SmitRo02.htm
# 	Successfully retrieved data for Ron Smith at URL 2: https://www.pro-football-reference.com/players/S/SmitRo02.htm
# Weighted Career AV: 12, Overall Rank: 7703
# An error occurred while extracting summary data: list index out of range
# Player (109): Bob Berry
# Fetching response for: https://www.pro-football-reference.com/players/B/BerrBo00.htm
# 	Successfully retrieved data for Bob Berry at URL 0: https://www.pro-football-reference.com/players/B/BerrBo00.htm
# Weighted Career AV: 38, Overall Rank: 2793
# Player (110): Jerry Rhome
# Fetching response for: https://www.pro-football-reference.com/players/R/RhomJe00.htm
# 	Successfully retrieved data for Jerry Rhome at URL 0: https://www.pro-football-reference.com/players/R/RhomJe00.htm
# Weighted Career AV: 7, Overall Rank: 9707
# Player (111): Jack Ankerson
# Fetching response for: https://www.pro-football-reference.com/players/A/AnkeJa00.htm
# 	Page not found: https://www.pro-football-reference.com/players/A/AnkeJa00.htm
# 	Page not found for Jack Ankerson at https://www.pro-football-reference.com/players/A/AnkeJa00.htm. Skipping further page attempts.
# 	No valid data found for Jack Ankerson after checking all pages
# Player (112): Terry Baker
# Fetching response for: https://www.pro-football-reference.com/players/B/BakeTe00.htm
# 	Successfully retrieved data for Terry Baker at URL 0: https://www.pro-football-reference.com/players/B/BakeTe00.htm
# Weighted Career AV: 6, Overall Rank: 10278
# An error occurred while extracting summary data: list index out of range
# Player (113): Dave Mathieson
# Fetching response for: https://www.pro-football-reference.com/players/M/MathDa00.htm
# 	Failed to retrieve valid data for Dave Mathieson with page number 00
# Fetching response for: https://www.pro-football-reference.com/players/M/MathDa01.htm
# 	Failed to retrieve valid data for Dave Mathieson with page number 01
# Fetching response for: https://www.pro-football-reference.com/players/M/MathDa02.htm
# 	Page not found: https://www.pro-football-reference.com/players/M/MathDa02.htm
# 	Page not found for Dave Mathieson at https://www.pro-football-reference.com/players/M/MathDa02.htm. Skipping further page attempts.
# 	No valid data found for Dave Mathieson after checking all pages
# Player (114): Don Trull
# Fetching response for: https://www.pro-football-reference.com/players/T/TrulDo00.htm
# 	Successfully retrieved data for Don Trull at URL 0: https://www.pro-football-reference.com/players/T/TrulDo00.htm
# Weighted Career AV: 17, Overall Rank: 6286
# Player (115): Pete Liske
# Fetching response for: https://www.pro-football-reference.com/players/L/LiskPe00.htm
# 	Successfully retrieved data for Pete Liske at URL 0: https://www.pro-football-reference.com/players/L/LiskPe00.htm
# Weighted Career AV: 18, Overall Rank: 6033
# Player (116): Bill Nelsen
# Fetching response for: https://www.pro-football-reference.com/players/N/NelsBi00.htm
# 	Successfully retrieved data for Bill Nelsen at URL 0: https://www.pro-football-reference.com/players/N/NelsBi00.htm
# Weighted Career AV: 54, Overall Rank: 1407
# Player (117): Mike Taliaferro
# Fetching response for: https://www.pro-football-reference.com/players/T/TaliMi00.htm
# 	Successfully retrieved data for Mike Taliaferro at URL 0: https://www.pro-football-reference.com/players/T/TaliMi00.htm
# Weighted Career AV: 13, Overall Rank: 7362
# Player (118): Daryle Lamonica
# Fetching response for: https://www.pro-football-reference.com/players/L/LamoDa00.htm
# 	Successfully retrieved data for Daryle Lamonica at URL 0: https://www.pro-football-reference.com/players/L/LamoDa00.htm
# Weighted Career AV: 74, Overall Rank: 558
# Player (119): Jim Turner
# Fetching response for: https://www.pro-football-reference.com/players/T/TurnJi00.htm
# 	Page not found: https://www.pro-football-reference.com/players/T/TurnJi00.htm
# 	Page not found for Jim Turner at https://www.pro-football-reference.com/players/T/TurnJi00.htm. Skipping further page attempts.
# 	No valid data found for Jim Turner after checking all pages
# Player (120): Roman Gabriel
# Fetching response for: https://www.pro-football-reference.com/players/G/GabrRo00.htm
# 	Successfully retrieved data for Roman Gabriel at URL 0: https://www.pro-football-reference.com/players/G/GabrRo00.htm
# Weighted Career AV: 98, Overall Rank: 165
# Player (121): Roman Gabriel
# Fetching response for: https://www.pro-football-reference.com/players/G/GabrRo00.htm
# 	Successfully retrieved data for Roman Gabriel at URL 0: https://www.pro-football-reference.com/players/G/GabrRo00.htm
# Weighted Career AV: 98, Overall Rank: 165
# Player (122): John Hadl
# Fetching response for: https://www.pro-football-reference.com/players/H/HadlJo00.htm
# 	Successfully retrieved data for John Hadl at URL 0: https://www.pro-football-reference.com/players/H/HadlJo00.htm
# Weighted Career AV: 106, Overall Rank: 97
# Player (123): Sonny Gibbs
# Fetching response for: https://www.pro-football-reference.com/players/G/GibbSo00.htm
# 	Successfully retrieved data for Sonny Gibbs at URL 0: https://www.pro-football-reference.com/players/G/GibbSo00.htm
# Weighted Career AV: 0, Overall Rank: 17659
# An error occurred: 'NoneType' object has no attribute 'group'
# Player (124): Eddie Wilson
# Fetching response for: https://www.pro-football-reference.com/players/W/WilsEd00.htm
# 	Successfully retrieved data for Eddie Wilson at URL 0: https://www.pro-football-reference.com/players/W/WilsEd00.htm
# Weighted Career AV: 3, Overall Rank: 12506
# Player (125): John Furman
# Fetching response for: https://www.pro-football-reference.com/players/F/FurmJo00.htm
# 	Failed to retrieve valid data for John Furman with page number 00
# Fetching response for: https://www.pro-football-reference.com/players/F/FurmJo01.htm
# 	Page not found: https://www.pro-football-reference.com/players/F/FurmJo01.htm
# 	Page not found for John Furman at https://www.pro-football-reference.com/players/F/FurmJo01.htm. Skipping further page attempts.
# 	No valid data found for John Furman after checking all pages
# Player (126): Glynn Griffing
# Fetching response for: https://www.pro-football-reference.com/players/G/GrifGl00.htm
# 	Successfully retrieved data for Glynn Griffing at URL 0: https://www.pro-football-reference.com/players/G/GrifGl00.htm
# Weighted Career AV: 2, Overall Rank: 13593
# Player (127): Jim Bakken
# Fetching response for: https://www.pro-football-reference.com/players/B/BakkJi00.htm
# 	Page not found: https://www.pro-football-reference.com/players/B/BakkJi00.htm
# 	Page not found for Jim Bakken at https://www.pro-football-reference.com/players/B/BakkJi00.htm. Skipping further page attempts.
# 	No valid data found for Jim Bakken after checking all pages
# Player (128): Wilburn Hollis
# Fetching response for: https://www.pro-football-reference.com/players/H/HollWi00.htm
# 	Page not found: https://www.pro-football-reference.com/players/H/HollWi00.htm
# 	Page not found for Wilburn Hollis at https://www.pro-football-reference.com/players/H/HollWi00.htm. Skipping further page attempts.
# 	No valid data found for Wilburn Hollis after checking all pages
# Player (129): Walt Rappold
# Fetching response for: https://www.pro-football-reference.com/players/R/RappWa00.htm
# 	Page not found: https://www.pro-football-reference.com/players/R/RappWa00.htm
# 	Page not found for Walt Rappold at https://www.pro-football-reference.com/players/R/RappWa00.htm. Skipping further page attempts.
# 	No valid data found for Walt Rappold after checking all pages
# Player (130): Gale Weidner
# Fetching response for: https://www.pro-football-reference.com/players/W/WeidGa00.htm
# 	Page not found: https://www.pro-football-reference.com/players/W/WeidGa00.htm
# 	Page not found for Gale Weidner at https://www.pro-football-reference.com/players/W/WeidGa00.htm. Skipping further page attempts.
# 	No valid data found for Gale Weidner after checking all pages
# Player (131): Charlie Furlow
# Fetching response for: https://www.pro-football-reference.com/players/F/FurlCh00.htm
# 	Page not found: https://www.pro-football-reference.com/players/F/FurlCh00.htm
# 	Page not found for Charlie Furlow at https://www.pro-football-reference.com/players/F/FurlCh00.htm. Skipping further page attempts.
# ...
# No 'Weighted Career AV' found.
# An error occurred while extracting summary data: 'NoneType' object has no attribute 'find'
# Player (1029): Max Duggan
# Fetching response for: https://www.pro-football-reference.com/players/D/DuggMa00.htm
# 	Successfully retrieved data for Max Duggan at URL 0: https://www.pro-football-reference.com/players/D/DuggMa00.htm
# No 'Weighted Career AV' found.
# An error occurred while extracting summary data: 'NoneType' object has no attribute 'find'
# Player (1030): Kenny Pickett
# Fetching response for: https://www.pro-football-reference.com/players/P/PickKe00.htm
# 	Successfully retrieved data for Kenny Pickett at URL 0: https://www.pro-football-reference.com/players/P/PickKe00.htm
# Weighted Career AV: 13, Overall Rank: 7362
# Player (1031): Desmond Ridder
# Fetching response for: https://www.pro-football-reference.com/players/R/RiddDe00.htm
# 	Successfully retrieved data for Desmond Ridder at URL 0: https://www.pro-football-reference.com/players/R/RiddDe00.htm
# Weighted Career AV: 12, Overall Rank: 7703
# Player (1032): Malik Willis
# Fetching response for: https://www.pro-football-reference.com/players/W/WillMa00.htm
# 	Failed to retrieve valid data for Malik Willis with page number 00
# Fetching response for: https://www.pro-football-reference.com/players/W/WillMa01.htm
# 	Failed to retrieve valid data for Malik Willis with page number 01
# Fetching response for: https://www.pro-football-reference.com/players/W/WillMa02.htm
# 	Failed to retrieve valid data for Malik Willis with page number 02
# Fetching response for: https://www.pro-football-reference.com/players/W/WillMa03.htm
# 	Failed to retrieve valid data for Malik Willis with page number 03
# Fetching response for: https://www.pro-football-reference.com/players/W/WillMa04.htm
# 	Failed to retrieve valid data for Malik Willis with page number 04
# 	No valid data found for Malik Willis after checking all pages
# Player (1033): Matt Corral
# Fetching response for: https://www.pro-football-reference.com/players/C/CorrMa00.htm
# 	Successfully retrieved data for Matt Corral at URL 0: https://www.pro-football-reference.com/players/C/CorrMa00.htm
# No 'Weighted Career AV' found.
# An error occurred while extracting summary data: 'NoneType' object has no attribute 'find'
# Player (1034): Bailey Zappe
# Fetching response for: https://www.pro-football-reference.com/players/Z/ZappBa00.htm
# 	Successfully retrieved data for Bailey Zappe at URL 0: https://www.pro-football-reference.com/players/Z/ZappBa00.htm
# Weighted Career AV: 2, Overall Rank: 13593
# Player (1035): Sam Howell
# Fetching response for: https://www.pro-football-reference.com/players/H/HoweSa00.htm
# 	Successfully retrieved data for Sam Howell at URL 0: https://www.pro-football-reference.com/players/H/HoweSa00.htm
# Weighted Career AV: 12, Overall Rank: 7703
# Player (1036): Chris Oladokun
# Fetching response for: https://www.pro-football-reference.com/players/O/OladCh00.htm
# 	Successfully retrieved data for Chris Oladokun at URL 0: https://www.pro-football-reference.com/players/O/OladCh00.htm
# No 'Weighted Career AV' found.
# An error occurred while extracting summary data: 'NoneType' object has no attribute 'find'
# Player (1037): Skylar Thompson
# Fetching response for: https://www.pro-football-reference.com/players/T/ThomSk00.htm
# 	Successfully retrieved data for Skylar Thompson at URL 0: https://www.pro-football-reference.com/players/T/ThomSk00.htm
# Weighted Career AV: 2, Overall Rank: 13593
# Player (1038): Brock Purdy
# Fetching response for: https://www.pro-football-reference.com/players/P/PurdBr00.htm
# 	Successfully retrieved data for Brock Purdy at URL 0: https://www.pro-football-reference.com/players/P/PurdBr00.htm
# Weighted Career AV: 24, Overall Rank: 4805
# Player (1039): Trevor Lawrence
# Fetching response for: https://www.pro-football-reference.com/players/L/LawrTr00.htm
# 	Successfully retrieved data for Trevor Lawrence at URL 0: https://www.pro-football-reference.com/players/L/LawrTr00.htm
# Weighted Career AV: 34, Overall Rank: 3269
# Player (1040): Zach Wilson
# Fetching response for: https://www.pro-football-reference.com/players/W/WilsZa00.htm
# 	Successfully retrieved data for Zach Wilson at URL 0: https://www.pro-football-reference.com/players/W/WilsZa00.htm
# Weighted Career AV: 13, Overall Rank: 7362
# Player (1041): Trey Lance
# Fetching response for: https://www.pro-football-reference.com/players/L/LancTr00.htm
# 	Successfully retrieved data for Trey Lance at URL 0: https://www.pro-football-reference.com/players/L/LancTr00.htm
# Weighted Career AV: 4, Overall Rank: 11668
# Player (1042): Justin Fields
# Fetching response for: https://www.pro-football-reference.com/players/F/FielJu00.htm
# 	Successfully retrieved data for Justin Fields at URL 0: https://www.pro-football-reference.com/players/F/FielJu00.htm
# Weighted Career AV: 34, Overall Rank: 3269
# Player (1043): Mac Jones
# Fetching response for: https://www.pro-football-reference.com/players/J/JoneMa00.htm
# 	Failed to retrieve valid data for Mac Jones with page number 00
# Fetching response for: https://www.pro-football-reference.com/players/J/JoneMa01.htm
# 	Failed to retrieve valid data for Mac Jones with page number 01
# Fetching response for: https://www.pro-football-reference.com/players/J/JoneMa02.htm
# 	Failed to retrieve valid data for Mac Jones with page number 02
# Fetching response for: https://www.pro-football-reference.com/players/J/JoneMa03.htm
# 	Failed to retrieve valid data for Mac Jones with page number 03
# Fetching response for: https://www.pro-football-reference.com/players/J/JoneMa04.htm
# 	Failed to retrieve valid data for Mac Jones with page number 04
# 	No valid data found for Mac Jones after checking all pages
# Player (1044): Kyle Trask
# Fetching response for: https://www.pro-football-reference.com/players/T/TrasKy00.htm
# 	Successfully retrieved data for Kyle Trask at URL 0: https://www.pro-football-reference.com/players/T/TrasKy00.htm
# Weighted Career AV: 0, Overall Rank: 17659
# An error occurred: 'NoneType' object has no attribute 'group'
# Player (1045): Kellen Mond
# Fetching response for: https://www.pro-football-reference.com/players/M/MondKe00.htm
# 	Successfully retrieved data for Kellen Mond at URL 0: https://www.pro-football-reference.com/players/M/MondKe00.htm
# Weighted Career AV: 0, Overall Rank: 17659
# An error occurred: 'NoneType' object has no attribute 'group'
# Player (1046): Davis Mills
# Fetching response for: https://www.pro-football-reference.com/players/M/MillDa00.htm
# 	Failed to retrieve valid data for Davis Mills with page number 00
# Fetching response for: https://www.pro-football-reference.com/players/M/MillDa01.htm
# 	Failed to retrieve valid data for Davis Mills with page number 01
# Fetching response for: https://www.pro-football-reference.com/players/M/MillDa02.htm
# 	Successfully retrieved data for Davis Mills at URL 2: https://www.pro-football-reference.com/players/M/MillDa02.htm
# Weighted Career AV: 15, Overall Rank: 6788
# Player (1047): Ian Book
# Fetching response for: https://www.pro-football-reference.com/players/B/BookIa00.htm
# 	Successfully retrieved data for Ian Book at URL 0: https://www.pro-football-reference.com/players/B/BookIa00.htm
# Weighted Career AV: 0, Overall Rank: 17659
# An error occurred: 'NoneType' object has no attribute 'group'
# Player (1048): Sam Ehlinger
# Fetching response for: https://www.pro-football-reference.com/players/E/EhliSa00.htm
# 	Successfully retrieved data for Sam Ehlinger at URL 0: https://www.pro-football-reference.com/players/E/EhliSa00.htm
# Weighted Career AV: 2, Overall Rank: 13593
# Player (1049): Joe Burrow
# Fetching response for: https://www.pro-football-reference.com/players/B/BurrJo00.htm
# 	Failed to retrieve valid data for Joe Burrow with page number 00
# Fetching response for: https://www.pro-football-reference.com/players/B/BurrJo01.htm
# 	Successfully retrieved data for Joe Burrow at URL 1: https://www.pro-football-reference.com/players/B/BurrJo01.htm
# Weighted Career AV: 44, Overall Rank: 2204
# Player (1050): Tua Tagovailoa
# Fetching response for: https://www.pro-football-reference.com/players/T/TagoTu00.htm
# 	Successfully retrieved data for Tua Tagovailoa at URL 0: https://www.pro-football-reference.com/players/T/TagoTu00.htm
# Weighted Career AV: 38, Overall Rank: 2793
# Player (1051): Justin Herbert
# Fetching response for: https://www.pro-football-reference.com/players/H/HerbJu00.htm
# 	Successfully retrieved data for Justin Herbert at URL 0: https://www.pro-football-reference.com/players/H/HerbJu00.htm
# Weighted Career AV: 52, Overall Rank: 1534
# Player (1052): Jordan Love
# Fetching response for: https://www.pro-football-reference.com/players/L/LoveJo00.htm
# 	Failed to retrieve valid data for Jordan Love with page number 00
# Fetching response for: https://www.pro-football-reference.com/players/L/LoveJo01.htm
# 	Page not found: https://www.pro-football-reference.com/players/L/LoveJo01.htm
# 	Page not found for Jordan Love at https://www.pro-football-reference.com/players/L/LoveJo01.htm. Skipping further page attempts.
# 	No valid data found for Jordan Love after checking all pages
# Player (1053): Jalen Hurts
# Fetching response for: https://www.pro-football-reference.com/players/H/HurtJa00.htm
# 	Successfully retrieved data for Jalen Hurts at URL 0: https://www.pro-football-reference.com/players/H/HurtJa00.htm
# Weighted Career AV: 56, Overall Rank: 1284
# Player (1054): Jacob Eason
# Fetching response for: https://www.pro-football-reference.com/players/E/EasoJa00.htm
# 	Successfully retrieved data for Jacob Eason at URL 0: https://www.pro-football-reference.com/players/E/EasoJa00.htm
# Weighted Career AV: 0, Overall Rank: 17659
# An error occurred: 'NoneType' object has no attribute 'group'
# Player (1055): James Morgan
# Fetching response for: https://www.pro-football-reference.com/players/M/MorgJa00.htm
# 	Successfully retrieved data for James Morgan at URL 0: https://www.pro-football-reference.com/players/M/MorgJa00.htm
# No 'Weighted Career AV' found.
# An error occurred while extracting summary data: 'NoneType' object has no attribute 'find'
# Player (1056): Jake Fromm
# Fetching response for: https://www.pro-football-reference.com/players/F/FromJa00.htm
# 	Successfully retrieved data for Jake Fromm at URL 0: https://www.pro-football-reference.com/players/F/FromJa00.htm
# Weighted Career AV: 1, Overall Rank: 15158
# Player (1057): Jake Luton
# Fetching response for: https://www.pro-football-reference.com/players/L/LutoJa00.htm
# 	Successfully retrieved data for Jake Luton at URL 0: https://www.pro-football-reference.com/players/L/LutoJa00.htm
# Weighted Career AV: 2, Overall Rank: 13593
# Player (1058): Cole McDonald
# Fetching response for: https://www.pro-football-reference.com/players/M/McDoCo00.htm
# 	Successfully retrieved data for Cole McDonald at URL 0: https://www.pro-football-reference.com/players/M/McDoCo00.htm
# No 'Weighted Career AV' found.
# An error occurred while extracting summary data: 'NoneType' object has no attribute 'find'
# Player (1059): Ben DiNucci
# Fetching response for: https://www.pro-football-reference.com/players/D/DiNuBe00.htm
# 	Successfully retrieved data for Ben DiNucci at URL 0: https://www.pro-football-reference.com/players/D/DiNuBe00.htm
# Weighted Career AV: 1, Overall Rank: 15158
# An error occurred: 'NoneType' object has no attribute 'group'
# Player (1060): Tommy Stevens
# Fetching response for: https://www.pro-football-reference.com/players/S/StevTo00.htm
# 	Failed to retrieve valid data for Tommy Stevens with page number 00
# Fetching response for: https://www.pro-football-reference.com/players/S/StevTo01.htm
# 	Successfully retrieved data for Tommy Stevens at URL 1: https://www.pro-football-reference.com/players/S/StevTo01.htm
# Weighted Career AV: 0, Overall Rank: 17659
# Player (1061): Nate Stanley
# Fetching response for: https://www.pro-football-reference.com/players/S/StanNa00.htm
# 	Successfully retrieved data for Nate Stanley at URL 0: https://www.pro-football-reference.com/players/S/StanNa00.htm
# No 'Weighted Career AV' found.
# An error occurred while extracting summary data: 'NoneType' object has no attribute 'find'
# Pages not found: ['Onree Jackson', 'Onree Jackson', 'Larry Good', 'Larry Good', 'Sonny Wade', 'Sonny Wade', 'Alan Pastrana', 'Alan Pastrana', 'Tim Carr', 'Tim Carr', 'Bob Belden', 'Bob Belden', 'Tom Boutwell', 'Tom Boutwell', 'Ed Roseborough', 'Ed Roseborough', 'Ed Hargett', 'Ed Hargett', "Buster O'Brien", "Buster O'Brien", 'Ronnie South', 'Ronnie South', 'John Schneider', 'John Schneider', 'Danny Holman', 'Danny Holman', 'Greg Barton', 'Greg Barton', 'Kim King', 'Kim King', 'Jim Alcorn', 'Jim Alcorn', 'Henry Johnson', 'Henry Johnson', 'Jim Haynie', 'Jim Haynie', 'Jeff Beaver', 'Jeff Beaver', 'Jimmy Raye', 'Jimmy Raye', 'Bob Lee', 'Bob Lee', 'Bob David', 'Bob David', 'Vidal Carlin', 'Vidal Carlin', 'Terry Southall', 'Terry Southall', 'Rick Egloff', 'Rick Egloff', 'Corey Colehour', 'Corey Colehour', 'Bruce Matte', 'Bruce Matte', 'John Foruria', 'John Foruria', 'Steve Laub', 'Steve Laub', 'Dave Bennett', 'Dave Bennett', 'Ben Monroe', 'Ben Monroe', 'Jack Lentz', 'Jack Lentz', 'Paul Brothers', 'Paul Brothers', 'Bill Buckner', 'Bill Buckner', 'Bob Biletnikoff', 'Bob Biletnikoff', 'Dan Talbott', 'Dan Talbott', 'Gary Snook', 'Gary Snook', 'Jack White', 'Mike Brundage', 'Mike Brundage', 'Ken Lucas', 'Ken Lucas', 'Dave Neilson', 'Dave Neilson', 'Bob Timberlake', 'Bob Timberlake', 'Tommy Myers', 'Tommy Myers', 'Brig Owens', 'Brig Owens', 'Jhn Hankinson', 'Jhn Hankinson', 'Pat Screen', 'Pat Screen', 'Dan Simrell', 'Dan Simrell', 'Tom LaFramboise', 'Tom LaFramboise', 'Billy Guy Anderson', 'Billy Guy Anderson', 'John Torok', 'John Torok', 'Craig Fertig', 'Craig Fertig', 'George Haffner', 'George Haffner', 'Perry Lee Dunn', 'Perry Lee Dunn', 'Billy Lothridge', 'Billy Lothridge', 'Henry Schichtle', 'Henry Schichtle', 'Jack Ankerson', 'Jack Ankerson', 'Dave Mathieson', 'Dave Mathieson', 'Jim Turner', 'Jim Turner', 'John Furman', 'John Furman', 'Jim Bakken', 'Jim Bakken', 'Wilburn Hollis', 'Wilburn Hollis', 'Walt Rappold', 'Walt Rappold', 'Gale Weidner', 'Gale Weidner', 'Charlie Furlow', 'Charlie Furlow', 'Mel Rideout', 'Mel Rideout', 'Joe Zuger', 'Joe Zuger', 'Bob Joiner', 'Bob Joiner', 'John Anabo', 'John Anabo', 'Ed Trancygier', 'Ed Trancygier', 'Jim Wright', 'Jim Wright', 'Dick Thornton', 'Dick Thornton', 'Jake Gibbs', 'Jake Gibbs', 'Lowndes Shingler', 'Lowndes Shingler', 'Howard Dyer', 'Howard Dyer', 'Jack Moynihan', 'Jack Moynihan', 'Don Jonas', 'Don Jonas', 'Ben Charles', 'Ben Charles', 'George Izo', 'George Izo', 'Charley Britt', 'Charley Britt', 'Jack Cummings', 'Jack Cummings', 'Dick Norman', 'Dick Norman', 'Jacky Lee', 'Jacky Lee', 'Bobby Waters', 'Bobby Waters', 'Dave Grosz', 'Dave Grosz', 'Jim Waldon', 'Jim Waldon', 'Don Allard', 'Don Allard', 'Jim Grazione', 'Jim Grazione', 'Mitch Ogiego', 'Mitch Ogiego', 'Bob Ptacek', 'Bob Ptacek', 'Frank Kremblas', 'Frank Kremblas', 'Dan Nolan', 'Dan Nolan', 'Jim Van Pelt', 'Jim Van Pelt', 'Al Jacks', 'Al Jacks', 'Mickey Trimarki', 'Mickey Trimarki', 'Ken (Model-T) Ford', 'Ken (Model-T) Ford', 'Tom Forestal', 'Tom Forestal', 'Ronnie Knox', 'Ronnie Knox', 'Bobby Cox', 'Bobby Cox', 'Jimmy Harris', 'Jimmy Harris', 'Chuck Curtis', 'Chuck Curtis', 'Wade Mitchell', 'Wade Mitchell', 'Corny Salvaterra', 'Corny Salvaterra', 'Kenny Ploen', 'Kenny Ploen', 'Gene Cichowski', 'Gene Cichowski', 'Ronnie Quillian', 'Ronnie Quillian', 'Bob Winters', 'Bob Winters', 'Gary Glick', 'Gary Glick', 'Em Lindbeck', 'Em Lindbeck', 'John Polzer', 'John Polzer', 'Tom Spiers', 'Tom Spiers', 'George Welsh', 'George Welsh', 'Eagle Day', 'Eagle Day', 'Eddie West', 'Eddie West', 'Pete Neft', 'Pete Neft', 'Bobby Fox', 'Bobby Fox', 'Jerry Gustafson', 'Jerry Gustafson', 'John Shearer', 'John Shearer', 'Bobby Lance', 'Bobby Lance', 'Rod Hermes', 'Rod Hermes', 'Johnny Borton', 'Johnny Borton', 'Charley Brackins', 'Charley Brackins', 'Pete Vann', 'Pete Vann', 'Bobby Garrett', 'Bobby Garrett', 'Ted Marchibroda', 'Ted Marchibroda', 'Eddie Crowder', 'Eddie Crowder', 'Dale Samuels', 'Dale Samuels', 'Charlie Maloy', 'Charlie Maloy', 'Bill  ...

# %%
display(f'rows : {len(combined_df)}; cols: {len(combined_df.columns)}')
display(combined_df.iloc[:,:15].tail(5))
display(combined_df.iloc[:,15:30].tail(5))
display(combined_df.iloc[:,30:45].tail(5))
display(combined_df.iloc[:,45:].tail(5))

# %% [markdown]
# ## PAUSE POINT: save dataframe and list to CSV and pickle

# %%
#Export csv

import csv

# combined_df     (DataFrame)
csv_path =  "../sourcing_artifacts/pro_fb_ref_output_combinedxx.csv"
combined_df.to_csv(csv_path, index=False)

# quarterback_fails  (list)
list_path = "../sourcing_artifacts/pro_fb_ref_output_failsxx.csv"
# Write the list to the CSV file as a single comma-separated row
with open(list_path, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(quarterback_fails)  # writerow instead of writerows to save as a single row

# %%
# Save as Pickle; pickle.dump to store data

import pickle

# combined_df     (DataFrame)
pkl_path1 = "../sourcing_artifacts/pfb_ref_sourcing_outputxx.pkl"
with open(pkl_path1, 'wb') as file:
    pickle.dump(combined_df, file)


# quarterback_fails  (list)
pkl_path2 = "../sourcing_artifacts/pfb_ref_sourcing_outputxx.pkl"
with open(pkl_path2, 'wb') as file:
    pickle.dump(quarterback_fails, file)

# %% [markdown]
# ### ** ALL REMAINING CELLS: NOT USED **

# %% [markdown]
# ## RESTORE POINT: load/restore dataframe and list from CSV and pickle

# %%
# Read the CSVs

# combined_df     (DataFrame)
csv_path = "../sourcing_artifacts/pfb_ref_sourcing_output_combined.csv"
combined_df_restore = pd.read_csv(csv_path)

display(f'rows : {len(combined_df_restore)}; cols: {len(combined_df_restore.columns)}')
display(combined_df_restore.head())


# quarterback_fails  (list)
list_path = "../sourcing_artifacts/pfb_ref_sourcing_output_fails.csv"
quarterback_fails_restore = []
# use next(reader) to retrieve the single row as a list, which simplifies the code and keeps quarterback_fails_restore as a flat list of items. 
#   Each item will correspond to an element from the original quarterback_fails list.
with open(list_path, mode='r') as file:
    reader = csv.reader(file)
    quarterback_fails_restore = next(reader)  # Using next() to get the first row as a single list

print(f'length: {len(quarterback_fails_restore)}')
print(f'restored {quarterback_fails_restore}')
# Out:
# 'rows : 656; cols: 58'
#              name throws  hall_of_fame     college
# 0       Greg Cook  Right           NaN  Cincinnati  \
# 1    Marty Domres  Right        8842.0    Columbia
# 2  Terry Hanratty  Right        8842.0  Notre Dame
# 3  Bobby Douglass   Left        8842.0      Kansas
# 4      Al Woodall  Right           NaN        Duke
#
#                   high_school  weighted_career_av  overall_rank
# 0                 Chillicothe                10.0        8386.0  \
# 1  Christian Brothers Academy                19.0        5811.0
# 2                      Butler                 8.0        9197.0
# 3                   El Dorado                37.0        2916.0
# 4                       Erwin                13.0        7362.0
#
#                                        college_stats           draft_team
# 0  https://www.sports-reference.com/cfb/players/g...   Cincinnati Bengals  \
# 1  https://www.sports-reference.com/cfb/players/m...   San Diego Chargers
# 2  https://www.sports-reference.com/cfb/players/t...  Pittsburgh Steelers
# 3  https://www.sports-reference.com/cfb/players/b...        Chicago Bears
# 4  https://www.sports-reference.com/cfb/players/a...        New York Jets
#
#    draft_round  ...  pass_rating  pass_sacked  pass_sacked_yds
# 0          1.0  ...         87.6         29.0            195.0  \
# 1          1.0  ...         53.8         79.0            588.0
# 2          2.0  ...         43.0         34.0            299.0
# 3          2.0  ...         48.5        180.0           1335.0
# 4          2.0  ...         60.3         60.0            455.0
#
#   pass_sacked_pct pass_net_yds_per_att  pass_adj_net_yds_per_att  comebacks
# 0           12.66                 7.29                      6.44        1.0  \
# 1            8.90                 4.86                      2.93        3.0
# 2            7.31                 4.75                      2.40        3.0
# 3           13.25                 3.80                      2.21        3.0
# 4           10.66                 4.47                      3.27        1.0
#
#    gwd    av  nickname
# 0  0.0  10.0       NaN
# 1  2.0  21.0       NaN
# 2  2.0   8.0       NaN
# 3  4.0  41.0       NaN
# 4  1.0  13.0       NaN
#
# [5 rows x 58 columns]
# length: 806
# restored ['Onree Jackson', 'Onree Jackson', 'Larry Good', 'Larry Good', 'Sonny Wade', 'Sonny Wade', 'Alan Pastrana', 'Alan Pastrana', 'Tim Carr', 'Tim Carr', 'Bob Belden', 'Bob Belden', 'Tom Boutwell', 'Tom Boutwell', 'Ed Roseborough', 'Ed Roseborough', 'Ed Hargett', 'Ed Hargett', "Buster O'Brien", "Buster O'Brien", 'Ronnie South', 'Ronnie South', 'John Schneider', 'John Schneider', 'Danny Holman', 'Danny Holman', 'Greg Barton', 'Greg Barton', 'Kim King', 'Kim King', 'Jim Alcorn', 'Jim Alcorn', 'Henry Johnson', 'Henry Johnson', 'Jim Haynie', 'Jim Haynie', 'Jeff Beaver', 'Jeff Beaver', 'Jimmy Raye', 'Jimmy Raye', 'Bob Lee', 'Bob Lee', 'Bob David', 'Bob David', 'Vidal Carlin', 'Vidal Carlin', 'Terry Southall', 'Terry Southall', 'Rick Egloff', 'Rick Egloff', 'Corey Colehour', 'Corey Colehour', 'Bruce Matte', 'Bruce Matte', 'John Foruria', 'John Foruria', 'Steve Laub', 'Steve Laub', 'Dave Bennett', 'Dave Bennett', 'Ben Monroe', 'Ben Monroe', 'Jack Lentz', 'Jack Lentz', 'Paul Brothers', 'Paul Brothers', 'Bill Buckner', 'Bill Buckner', 'Bob Biletnikoff', 'Bob Biletnikoff', 'Dan Talbott', 'Dan Talbott', 'Gary Snook', 'Gary Snook', 'Jack White', 'Mike Brundage', 'Mike Brundage', 'Ken Lucas', 'Ken Lucas', 'Dave Neilson', 'Dave Neilson', 'Bob Timberlake', 'Bob Timberlake', 'Tommy Myers', 'Tommy Myers', 'Brig Owens', 'Brig Owens', 'Jhn Hankinson', 'Jhn Hankinson', 'Pat Screen', 'Pat Screen', 'Dan Simrell', 'Dan Simrell', 'Tom LaFramboise', 'Tom LaFramboise', 'Billy Guy Anderson', 'Billy Guy Anderson', 'John Torok', 'John Torok', 'Craig Fertig', 'Craig Fertig', 'George Haffner', 'George Haffner', 'Perry Lee Dunn', 'Perry Lee Dunn', 'Billy Lothridge', 'Billy Lothridge', 'Henry Schichtle', 'Henry Schichtle', 'Jack Ankerson', 'Jack Ankerson', 'Dave Mathieson', 'Dave Mathieson', 'Jim Turner', 'Jim Turner', 'John Furman', 'John Furman', 'Jim Bakken', 'Jim Bakken', 'Wilburn Hollis', 'Wilburn Hollis', 'Walt Rappold', 'Walt Rappold', 'Gale Weidner', 'Gale Weidner', 'Charlie Furlow', 'Charlie Furlow', 'Mel Rideout', 'Mel Rideout', 'Joe Zuger', 'Joe Zuger', 'Bob Joiner', 'Bob Joiner', 'John Anabo', 'John Anabo', 'Ed Trancygier', 'Ed Trancygier', 'Jim Wright', 'Jim Wright', 'Dick Thornton', 'Dick Thornton', 'Jake Gibbs', 'Jake Gibbs', 'Lowndes Shingler', 'Lowndes Shingler', 'Howard Dyer', 'Howard Dyer', 'Jack Moynihan', 'Jack Moynihan', 'Don Jonas', 'Don Jonas', 'Ben Charles', 'Ben Charles', 'George Izo', 'George Izo', 'Charley Britt', 'Charley Britt', 'Jack Cummings', 'Jack Cummings', 'Dick Norman', 'Dick Norman', 'Jacky Lee', 'Jacky Lee', 'Bobby Waters', 'Bobby Waters', 'Dave Grosz', 'Dave Grosz', 'Jim Waldon', 'Jim Waldon', 'Don Allard', 'Don Allard', 'Jim Grazione', 'Jim Grazione', 'Mitch Ogiego', 'Mitch Ogiego', 'Bob Ptacek', 'Bob Ptacek', 'Frank Kremblas', 'Frank Kremblas', 'Dan Nolan', 'Dan Nolan', 'Jim Van Pelt', 'Jim Van Pelt', 'Al Jacks', 'Al Jacks', 'Mickey Trimarki', 'Mickey Trimarki', 'Ken (Model-T) Ford', 'Ken (Model-T) Ford', 'Tom Forestal', 'Tom Forestal', 'Ronnie Knox', 'Ronnie Knox', 'Bobby Cox', 'Bobby Cox', 'Jimmy Harris', 'Jimmy Harris', 'Chuck Curtis', 'Chuck Curtis', 'Wade Mitchell', 'Wade Mitchell', 'Corny Salvaterra', 'Corny Salvaterra', 'Kenny Ploen', 'Kenny Ploen', 'Gene Cichowski', 'Gene Cichowski', 'Ronnie Quillian', 'Ronnie Quillian', 'Bob Winters', 'Bob Winters', 'Gary Glick', 'Gary Glick', 'Em Lindbeck', 'Em Lindbeck', 'John Polzer', 'John Polzer', 'Tom Spiers', 'Tom Spiers', 'George Welsh', 'George Welsh', 'Eagle Day', 'Eagle Day', 'Eddie West', 'Eddie West', 'Pete Neft', 'Pete Neft', 'Bobby Fox', 'Bobby Fox', 'Jerry Gustafson', 'Jerry Gustafson', 'John Shearer', 'John Shearer', 'Bobby Lance', 'Bobby Lance', 'Rod Hermes', 'Rod Hermes', 'Johnny Borton', 'Johnny Borton', 'Charley Brackins', 'Charley Brackins', 'Pete Vann', 'Pete Vann', 'Bobby Garrett', 'Bobby Garrett', 'Ted Marchibroda', 'Ted Marchibroda', 'Eddie Crowder', 'Eddie Crowder', 'Dale Samuels', 'Dale Samuels', 'Charlie Maloy', 'Charlie Maloy', 'Bill Brehany' ...

# %%
# Read the PKls

# combined_df     (DataFrame)
pkl_path1 = "../sourcing_artifacts/pfb_ref_sourcing_output_combined.pkl"
with open(pkl_path1, 'rb') as f:
    combined_df_restore = pickle.load(f)

display(f'rows : {len(combined_df_restore)}; cols: {len(combined_df_restore.columns)}')
display(combined_df_restore.head())


# quarterback_fails  (list)
pkl_path2 = "../sourcing_artifacts/pfb_ref_sourcingoutput_fails.pkl"
with open(pkl_path2, 'rb') as f:
    quarterback_fails_restore = pickle.load(f)

display(f'length: {len(quarterback_fails_restore)}')
display(f'restored {quarterback_fails_restore}')
# Out:
# 'rows : 656; cols: 58'
#              name throws hall_of_fame     college                 high_school
# 0       Greg Cook  Right               Cincinnati                 Chillicothe  \
# 1    Marty Domres  Right         8842    Columbia  Christian Brothers Academy
# 2  Terry Hanratty  Right         8842  Notre Dame                      Butler
# 3  Bobby Douglass   Left         8842      Kansas                   El Dorado
# 4      Al Woodall  Right                     Duke                       Erwin
#
#   weighted_career_av overall_rank
# 0                 10         8386  \
# 1                 19         5811
# 2                  8         9197
# 3                 37         2916
# 4                 13         7362
#
#                                        college_stats           draft_team
# 0  https://www.sports-reference.com/cfb/players/g...   Cincinnati Bengals  \
# 1  https://www.sports-reference.com/cfb/players/m...   San Diego Chargers
# 2  https://www.sports-reference.com/cfb/players/t...  Pittsburgh Steelers
# 3  https://www.sports-reference.com/cfb/players/b...        Chicago Bears
# 4  https://www.sports-reference.com/cfb/players/a...        New York Jets
#
#   draft_round  ... pass_rating pass_sacked pass_sacked_yds pass_sacked_pct
# 0           1  ...        87.6          29             195           12.66  \
# 1           1  ...        53.8          79             588            8.90
# 2           2  ...        43.0          34             299            7.31
# 3           2  ...        48.5         180            1335           13.25
# 4           2  ...        60.3          60             455           10.66
#
#   pass_net_yds_per_att pass_adj_net_yds_per_att comebacks gwd  av nickname
# 0                 7.29                     6.44         1   0  10      NaN
# 1                 4.86                     2.93         3   2  21      NaN
# 2                 4.75                     2.40         3   2   8      NaN
# 3                 3.80                     2.21         3   4  41      NaN
# 4                 4.47                     3.27         1   1  13      NaN
#
# [5 rows x 58 columns]
# 'length: 806'
# 'restored [\'Onree Jackson\', \'Onree Jackson\', \'Larry Good\', \'Larry Good\', \'Sonny Wade\', \'Sonny Wade\', \'Alan Pastrana\', \'Alan Pastrana\', \'Tim Carr\', \'Tim Carr\', \'Bob Belden\', \'Bob Belden\', \'Tom Boutwell\', \'Tom Boutwell\', \'Ed Roseborough\', \'Ed Roseborough\', \'Ed Hargett\', \'Ed Hargett\', "Buster O\'Brien", "Buster O\'Brien", \'Ronnie South\', \'Ronnie South\', \'John Schneider\', \'John Schneider\', \'Danny Holman\', \'Danny Holman\', \'Greg Barton\', \'Greg Barton\', \'Kim King\', \'Kim King\', \'Jim Alcorn\', \'Jim Alcorn\', \'Henry Johnson\', \'Henry Johnson\', \'Jim Haynie\', \'Jim Haynie\', \'Jeff Beaver\', \'Jeff Beaver\', \'Jimmy Raye\', \'Jimmy Raye\', \'Bob Lee\', \'Bob Lee\', \'Bob David\', \'Bob David\', \'Vidal Carlin\', \'Vidal Carlin\', \'Terry Southall\', \'Terry Southall\', \'Rick Egloff\', \'Rick Egloff\', \'Corey Colehour\', \'Corey Colehour\', \'Bruce Matte\', \'Bruce Matte\', \'John Foruria\', \'John Foruria\', \'Steve Laub\', \'Steve Laub\', \'Dave Bennett\', \'Dave Bennett\', \'Ben Monroe\', \'Ben Monroe\', \'Jack Lentz\', \'Jack Lentz\', \'Paul Brothers\', \'Paul Brothers\', \'Bill Buckner\', \'Bill Buckner\', \'Bob Biletnikoff\', \'Bob Biletnikoff\', \'Dan Talbott\', \'Dan Talbott\', \'Gary Snook\', \'Gary Snook\', \'Jack White\', \'Mike Brundage\', \'Mike Brundage\', \'Ken Lucas\', \'Ken Lucas\', \'Dave Neilson\', \'Dave Neilson\', \'Bob Timberlake\', \'Bob Timberlake\', \'Tommy Myers\', \'Tommy Myers\', \'Brig Owens\', \'Brig Owens\', \'Jhn Hankinson\', \'Jhn Hankinson\', \'Pat Screen\', \'Pat Screen\', \'Dan Simrell\', \'Dan Simrell\', \'Tom LaFramboise\', \'Tom LaFramboise\', \'Billy Guy Anderson\', \'Billy Guy Anderson\', \'John Torok\', \'John Torok\', \'Craig Fertig\', \'Craig Fertig\', \'George Haffner\', \'George Haffner\', \'Perry Lee Dunn\', \'Perry Lee Dunn\', \'Billy Lothridge\', \'Billy Lothridge\', \'Henry Schichtle\', \'Henry Schichtle\', \'Jack Ankerson\', \'Jack Ankerson\', \'Dave Mathieson\', \'Dave Mathieson\', \'Jim Turner\', \'Jim Turner\', \'John Furman\', \'John Furman\', \'Jim Bakken\', \'Jim Bakken\', \'Wilburn Hollis\', \'Wilburn Hollis\', \'Walt Rappold\', \'Walt Rappold\', \'Gale Weidner\', \'Gale Weidner\', \'Charlie Furlow\', \'Charlie Furlow\', \'Mel Rideout\', \'Mel Rideout\', \'Joe Zuger\', \'Joe Zuger\', \'Bob Joiner\', \'Bob Joiner\', \'John Anabo\', \'John Anabo\', \'Ed Trancygier\', \'Ed Trancygier\', \'Jim Wright\', \'Jim Wright\', \'Dick Thornton\', \'Dick Thornton\', \'Jake Gibbs\', \'Jake Gibbs\', \'Lowndes Shingler\', \'Lowndes Shingler\', \'Howard Dyer\', \'Howard Dyer\', \'Jack Moynihan\', \'Jack Moynihan\', \'Don Jonas\', \'Don Jonas\', \'Ben Charles\', \'Ben Charles\', \'George Izo\', \'George Izo\', \'Charley Britt\', \'Charley Britt\', \'Jack Cummings\', \'Jack Cummings\', \'Dick Norman\', \'Dick Norman\', \'Jacky Lee\', \'Jacky Lee\', \'Bobby Waters\', \'Bobby Waters\', \'Dave Grosz\', \'Dave Grosz\', \'Jim Waldon\', \'Jim Waldon\', \'Don Allard\', \'Don Allard\', \'Jim Grazione\', \'Jim Grazione\', \'Mitch Ogiego\', \'Mitch Ogiego\', \'Bob Ptacek\', \'Bob Ptacek\', \'Frank Kremblas\', \'Frank Kremblas\', \'Dan Nolan\', \'Dan Nolan\', \'Jim Van Pelt\', \'Jim Van Pelt\', \'Al Jacks\', \'Al Jacks\', \'Mickey Trimarki\', \'Mickey Trimarki\', \'Ken (Model-T) Ford\', \'Ken (Model-T) Ford\', \'Tom Forestal\', \'Tom Forestal\', \'Ronnie Knox\', \'Ronnie Knox\', \'Bobby Cox\', \'Bobby Cox\', \'Jimmy Harris\', \'Jimmy Harris\', \'Chuck Curtis\', \'Chuck Curtis\', \'Wade Mitchell\', \'Wade Mitchell\', \'Corny Salvaterra\', \'Corny Salvaterra\', \'Kenny Ploen\', \'Kenny Ploen\', \'Gene Cichowski\', \'Gene Cichowski\', \'Ronnie Quillian\', \'Ronnie Quillian\', \'Bob Winters\', \'Bob Winters\', \'Gary Glick\', \'Gary Glick\', \'Em Lindbeck\', \'Em Lindbeck\', \'John Polzer\', \'John Polzer\', \'Tom Spiers\', \'Tom Spiers\', \'George Welsh\', \'George Welsh\', \'Eagle Day\', \'Eagle Day\', \'Eddie West\', \'Eddie West\', \'Pete Neft\', \' ...

# %%
display(combined_df.iloc[:,:15].tail(5))
display(combined_df.iloc[:,15:30].tail(5))
display(combined_df.iloc[:,30:45].tail(5))
display(combined_df.iloc[:,45:].tail(5))
display(len(quarterback_fails))
# Out:
#               name throws hall_of_fame     college    high_school
# 651     Jake Luton  Right                    Idaho                 \
# 652  Cole McDonald                          Hawaii
# 653    Ben DiNucci  Right               Pittsburgh  Pine-Richland
# 654  Tommy Stevens  Right                 Penn St.
# 655   Nate Stanley                            Iowa
#
#     weighted_career_av overall_rank
# 651                  2        13593  \
# 652
# 653                  1        15158
# 654                  0        17659
# 655
#
#                                          college_stats            draft_team
# 651  https://www.sports-reference.com/cfb/players/j...  Jacksonville Jaguars  \
# 652  https://www.sports-reference.com/cfb/players/c...      Tennessee Titans
# 653  https://www.sports-reference.com/cfb/players/b...        Dallas Cowboys
# 654  https://www.sports-reference.com/cfb/players/t...    New Orleans Saints
# 655  https://www.sports-reference.com/cfb/players/n...     Minnesota Vikings
#
#     draft_round draft_pick draft_year games_played approximate_value qb_record
# 651           6        189       2020            3                 2     0-3-0
# 652           7        224       2020          N/A               N/A       N/A
# 653           7        231       2020            3                 1     0-1-0
# 654           7        240       2020            1               N/A       N/A
# 655           7        244       2020          N/A               N/A       N/A
#     completion_percentage passing_yards yards_per_attempt touchdowns
# 651                  54.5           624               5.7          2  \
# 652                   N/A           N/A               N/A        N/A
# 653                  53.5           219               5.1          0
# 654                   N/A           N/A               N/A        N/A
# 655                   N/A           N/A               N/A        N/A
#
#     interceptions fantasy_points all_star uniforms          when_born
# 651             6           28.3      N/A      N/A     April 11, 1996  \
# 652           N/A            N/A      N/A      N/A       May 20, 1998
# 653             0            7.0      N/A      N/A  November 24, 1996
# 654           N/A            N/A      N/A      N/A  December 15, 1996
# 655           N/A            N/A      N/A      N/A    August 26, 1997
#
#            where_born height weight pass_yards   TD superbowls
# 651    Marysville, WA    6-6    224        624    2        NaN
# 652               NaN    6-3    215        NaN  NaN        NaN
# 653       Atlanta, GA    6-2    215        219  NaN        NaN
# 654  Indianapolis, IN    6-5    235        NaN  NaN        NaN
# 655               NaN    6-4    235        NaN  NaN        NaN
#     retire_year years games games_started qb_rec pass_cmp pass_att
# 651        2020  1 Yr     3             3  0-3-0       60      110  \
# 652         NaN
# 653         NaN  1 Yr     3             1  0-1-0       23       43
# 654        2020  1 Yr     1             0      4       24        0
# 655         NaN
#
#     pass_cmp_pct pass_yds pass_td pass_td_pct pass_int pass_int_pct pass_long
# 651         54.5      624       2         1.8        6          5.5        31  \
# 652
# 653         53.5      219       0         0.0        0          0.0        11
# 654            2    100.0      10         6.0     24.0          4.0         0
# 655
#
#     pass_yds_per_att
# 651             41.0
# 652
# 653             34.0
# 654                0
# 655
#     pass_adj_yds_per_att pass_yds_per_cmp pass_yds_per_g pass_rating
# 651                   73              5.7           3.58        10.4  \
# 652
# 653                   32              5.1           5.09         9.5
# 654                    0                0              0         0.0
# 655
#
#     pass_sacked pass_sacked_yds pass_sacked_pct pass_net_yds_per_att
# 651       208.0            54.5                                    7  \
# 652
# 653        73.0            67.9                                    7
# 654         0.0               4             6.0                   24
# 655
#
#     pass_adj_net_yds_per_att comebacks   gwd    av nickname
# 651                       52      5.98  4.89  2.92      NaN
# 652                                                     NaN
# 653                       73     14.00  2.92  2.92      NaN
# 654                        0         0     0            NaN
# 655                                                     NaN
# 806

# %% [markdown]
# ### Bring in nfl_career_statistics.csv  to get QB names, etc.

# %%
# get lists of QBs to get data for:
rel_path = "../Data_Artifacts/nfl_career_statistics.csv"
qb_name_df = pd.read_csv(rel_path)
print(len(qb_name_df))

qb_name_df.head()

# import os
# absolute_path = os.path.abspath(rel_path)
# print(f"Absolute path: {absolute_path}")

# # Check if the file exists and open it with the default application
# if os.path.exists(absolute_path):
#     os.startfile(absolute_path)
#     print('Opened with default application.')
# else:
#     print(f'File not found at: {absolute_path}')
# Out:
# 637
#                player  drafted  yrs_played
# 0           Tom Brady   2000.0        23.0  \
# 1          Drew Brees   2001.0        20.0
# 2      Peyton Manning   1998.0        18.0
# 3         Brett Favre   1991.0        20.0
# 4  Ben Roethlisberger   2004.0        18.0
#
#                                        teams  hof    wAV  earnings_mils
# 0                 ['Patriots', 'Buccaneers']  0.0  184.0        317.620  \
# 1                     ['Saints', 'Chargers']  0.0  167.0        273.933
# 2                       ['Colts', 'Broncos']  1.0  176.0        247.714
# 3  ['Packers', 'Vikings', 'Jets', 'Falcons']  1.0  158.0        141.407
# 4                               ['Steelers']  0.0  131.0        266.724
#
#    comp_%  pass_rating    comp      att  pass_yds     TD  pass_yds_game
# 0    64.3         97.2  7753.0  12050.0   89214.0  649.0          266.0  \
# 1    67.7         98.7  7142.0  10551.0   80358.0  571.0          280.0
# 2    65.3         96.5  6125.0   9380.0   71940.0  539.0          270.0
# 3    62.0         86.0  6300.0  10169.0   71838.0  508.0          237.0
# 4    64.4         93.5  5440.0   8443.0   64088.0  418.0          257.0
#
#      int  int_%  pick_6  sacks   4QC   GWD
# 0  212.0    1.8    18.0  565.0  46.0  58.0
# 1  243.0    2.3    27.0  420.0  36.0  53.0
# 2  251.0    2.7    27.0  303.0  43.0  54.0
# 3  336.0    3.3    32.0  525.0  28.0  43.0
# 4  211.0    2.5    18.0  554.0  41.0  53.0
